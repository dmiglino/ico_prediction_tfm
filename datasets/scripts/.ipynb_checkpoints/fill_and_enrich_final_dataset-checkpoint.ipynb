# %%
# TODO - Eliminar claves antes de commitear!
# %env CMC_API_KEY="87f241ea-b56c-4a2f-9707-e25b4352ceb6"
# %env FOUNDI_PUBLIC_KEY="5e6fc744cf305a8fea1e5669057c5d11"
# %env FOUNDI_PRIVATE_KEY="3f824123907803e8b9a402ed7bdb0dd2"
# Out:
# env: CMC_API_KEY="87f241ea-b56c-4a2f-9707-e25b4352ceb6"
# env: FOUNDI_PUBLIC_KEY="5e6fc744cf305a8fea1e5669057c5d11"
# env: FOUNDI_PRIVATE_KEY="3f824123907803e8b9a402ed7bdb0dd2"

# %%
# %% [markdown]
# # Enriquecimiento ex-ante de ICOs (CG, CMC, Paprika, FoundICO)
# Completa datos faltantes del dataset final sin pisar valores existentes (a menos que se indique).
# Respeta ex-ante si se activa EXANTE_ONLY para evitar leakage.

# %%
import os, re, json, time, base64, hmac, hashlib
from typing import Dict, Any, Optional
import numpy as np
import pandas as pd
import requests
import unicodedata
from difflib import SequenceMatcher
from urllib.parse import quote

# === Rutas ===
#IN_PATH  = "../join/ico_exante_features_v1.csv"       # dataset final actual
#OUT_PATH = "../join/ico_exante_enriched_v1.csv"       # salida enriquecida
CACHE_PATH = ".cache_enrich.json"                      # cache local
IN_PATH  = "../final/ico_dataset_final_v2_clean.csv"       # dataset final actual
OUT_PATH = "../final/ico_dataset_final_v2_clean_enriquecido.csv"       # salida enriquecida

# === Flags ===
EXANTE_ONLY = True          # limitar a features pre-ICO (evita leakage)
OVERWRITE_MISSING = True    # solo completar vacíos (recomendado)
MAX_ROWS = 0                # 0 = todas las filas, >0 para depurar parcial
FOUN_FIND_MAX_PAGES = 40    # paginado máximo en FoundICO (búsqueda fuzzy)

# === Credenciales (setearlas como variables de entorno) ===
CMC_API_KEY  = os.getenv("CMC_API_KEY")
FOUN_PUB     = os.getenv("FOUNDI_PUBLIC_KEY")
FOUN_PRIV    = os.getenv("FOUNDI_PRIVATE_KEY")
CG_API_KEY   = os.getenv("CG_API_KEY")

CMC_API_KEY  = '87f241ea-b56c-4a2f-9707-e25b4352ceb6'
FOUN_PUB     = '5e6fc744cf305a8fea1e5669057c5d11'
FOUN_PRIV    = '3f824123907803e8b9a402ed7bdb0dd2'

# Rate limits suaves
SLEEP_CG   = 0.25
SLEEP_CMC  = 0.35
SLEEP_PAP  = 0.25
SLEEP_FOUN = 0.45

USER_AGENT = "TFM-ICO-Enricher/1.0 (+local)"
HEADERS_JSON = {
    "User-Agent": USER_AGENT,
    "Accept": "application/json",
    "Content-Type": "application/json",
}

# %%
# %% Utilidades (cache, normalizadores, parseos)

def load_cache(path: str) -> Dict[str, Any]:
    if os.path.exists(path):
        try:
            with open(path, "r", encoding="utf-8") as f:
                return json.load(f)
        except Exception:
            return {}
    return {}

def save_cache(cache: Dict[str, Any], path: str):
    try:
        with open(path, "w", encoding="utf-8") as f:
            json.dump(cache, f, ensure_ascii=False, indent=2)
    except Exception:
        pass

def normalize_text(x) -> str:
    if x is None or (isinstance(x, float) and np.isnan(x)): return ""
    s = str(x).strip()
    return re.sub(r"\s+", " ", s)

def similar(a: str, b: str) -> float:
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

def parse_money_like(x) -> Optional[float]:
    if x is None or (isinstance(x, float) and np.isnan(x)): return None
    s = str(x).lower().replace(",", "").replace("$", "").strip()
    mult = 1.0
    if s.endswith("b"): mult = 1e9; s = re.sub(r"b$", "", s)
    elif s.endswith("m"): mult = 1e6; s = re.sub(r"m$", "", s)
    elif s.endswith("k"): mult = 1e3; s = re.sub(r"k$", "", s)
    nums = re.findall(r"[\d.]+", s)
    return float(nums[0]) * mult if nums else None

def to_int(x) -> Optional[int]:
    try:
        if x is None or (isinstance(x, float) and np.isnan(x)): return None
        return int(float(x))
    except Exception:
        return None

def boolify(x) -> Optional[int]:
    if x is None or (isinstance(x, float) and np.isnan(x)): return None
    s = str(x).strip().lower()
    if s in {"1", "true", "yes", "y", "si", "sí"}: return 1
    if s in {"0", "false", "no", "n"}: return 0
    return None

def to_slug(s: str) -> str:
    if s is None: return ""
    s = str(s).strip().lower()
    # normalizar acentos
    s = unicodedata.normalize("NFKD", s).encode("ascii","ignore").decode("ascii")
    s = s.replace("&","and")
    s = re.sub(r"[^a-z0-9]+", "-", s)  # mantener guiones
    s = re.sub(r"-+", "-", s).strip("-")
    return s

def is_nonempty(x):
    return x not in [None, "", [], {}, np.nan]

# %%
# %% Clientes API (CoinGecko, CMC, CoinPaprika, FoundICO)

class CoinGecko:
    def __init__(self, api_key: Optional[str] = None):
        self.api_key = api_key
        self.base = "https://api.coingecko.com/api/v3"
        self.headers = {"User-Agent": USER_AGENT}
        if api_key:
            self.headers["x-cg-pro-api-key"] = api_key

    def search(self, query: str):
        url = f"{self.base}/search?query={quote(query)}"
        r = requests.get(url, headers=self.headers, timeout=30)
        if r.status_code != 200: time.sleep(SLEEP_CG); return None
        data = r.json()
        coins = data.get("coins", [])
        time.sleep(SLEEP_CG)
        return coins[0] if coins else None

    def get_coin(self, cg_id: str):
        url = f"{self.base}/coins/{cg_id}"
        params = {"localization":"false","tickers":"false","market_data":"false","community_data":"true","developer_data":"true","sparkline":"false"}
        r = requests.get(url, headers=self.headers, params=params, timeout=30)
        if r.status_code != 200: time.sleep(SLEEP_CG); return None
        payload = r.json()
        time.sleep(SLEEP_CG)
        return payload

    def resolve(self, symbol: str, name: str):
        q = symbol or name
        if not q: return None
        hit = self.search(q)
        if not hit and name:
            hit = self.search(name)
        if not hit: return None
        cg_id = hit.get("id")
        full = self.get_coin(cg_id) if cg_id else None
        if not full: return None
        links = (full.get("links") or {})
        return {
            "source": "coingecko",
            "cg_id": cg_id,
            "token_symbol": full.get("symbol"),
            "token_name": full.get("name"),
            "market_cap_rank": links.get("market_cap_rank"),
            "sentiment_votes_up_percentage": links.get("sentiment_votes_up_percentage"),
            "sentiment_votes_down_percentage": links.get("sentiment_votes_down_percentage"),
            "homepage": (links.get("homepage") or [None])[0],
            "whitepaper_url": links.get("whitepaper"),
            "github_url": (links.get("repos_url") or {}).get("github", [None])[0] if links.get("repos_url") else None,
            "twitter_url": links.get("twitter_screen_name") and f"https://twitter.com/{links.get('twitter_screen_name')}",
            "telegram_url": links.get("telegram_channel_identifier") and f"https://t.me/{links.get('telegram_channel_identifier')}",
            "reddit_url": links.get("subreddit_url"),
            "has_github": 1 if (links.get("repos_url") and links["repos_url"].get("github")) else None,
        }

# ===== CoinMarketCap =====
class CoinMarketCap:
    def __init__(self, api_key: Optional[str]):
        self.api_key = api_key
        self.base = "https://pro-api.coinmarketcap.com"
        self.headers = {
            "User-Agent": "TFM-ICO-Enricher/1.1",
            "Accept": "application/json"
        }
        if api_key:
            self.headers["X-CMC_PRO_API_KEY"] = api_key
        # cache en memoria para evitar hits repetidos
        self._cache_symbol = {}
        self._cache_slug   = {}
        self._cache_mapall = None

    def _get(self, path, params):
        if not self.api_key:
            return None
        try:
            r = requests.get(f"{self.base}{path}", headers=self.headers, params=params, timeout=30)
            if r.status_code != 200:
                # log corto para depurar
                # print(f"[CMC] HTTP {r.status_code} path={path} params={params} resp={r.text}")
                time.sleep(SLEEP_CMC)
                return None
            data = r.json()
            time.sleep(SLEEP_CMC)
            #print(f"[CMC] {data}")
            return data
        except Exception as e:
            #print(f"[CMC] error: {e}")
            return None

    def _info_by_id(self, cmc_id: int):
        data = self._get("/v2/cryptocurrency/info", {"id": str(cmc_id)})
        if not data: return None
        return (data.get("data") or {}).get(str(cmc_id))

    def _info_by_symbol(self, symbol: str):
        # v2/info acepta 'symbol' (coma-separado), aprovechamos para exact match
        data = self._get("/v2/cryptocurrency/info", {"symbol": symbol.upper()})
        if not data: return None
        dd = data.get("data") or {}
        # puede devolver múltiples entradas para el mismo símbolo
        # elegimos la primera
        for _, v in dd.items():
            return v  # primer match
        return None

    def _map_by_symbol(self, symbol: str):
        symbol = symbol.upper().strip()
        if symbol in self._cache_symbol:
            return self._cache_symbol[symbol]
        data = self._get("/v1/cryptocurrency/map", {
            "symbol": symbol,
            "listing_status": "active,inactive,untracked",
            "aux": "platform,first_historical_data,last_historical_data,is_active,status"
        })
        arr = (data or {}).get("data") or []
        out = arr[0] if arr else None
        self._cache_symbol[symbol] = out
        return out

    def _map_all(self):
        if self._cache_mapall is not None:
            return self._cache_mapall
        data = self._get("/v1/cryptocurrency/map", {
            "listing_status": "active,inactive,untracked",
            "aux": "platform,first_historical_data,last_historical_data,is_active,status"
        })
        df = None
        if data and data.get("data"):
            df = pd.DataFrame(data["data"])
        self._cache_mapall = df
        return df

    def _map_by_slug(self, slug: str):
        slug = slug.strip().lower()
        if slug in self._cache_slug:
            return self._cache_slug[slug]
        df = self._map_all()
        if df is None or df.empty:
            self._cache_slug[slug] = None
            return None
        hit = df[df["slug"].astype(str).str.lower() == slug]
        out = hit.iloc[0].to_dict() if not hit.empty else None
        self._cache_slug[slug] = out
        return out

    def resolve(self, symbol: str, name: str):
        if not self.api_key:
            return None

        symbol = (symbol or "").strip().upper()
        name   = (name or "").strip()
        # 1) intento rápido: info por símbolo (devuelve urls directas)
        if symbol:
            info = self._info_by_symbol(symbol)
            if info:
                # CoinMarketCap puede devolver:
                # - dict con IDs (p.ej. {'1027': {...}})
                # - lista de dicts (p.ej. [{'id':..., 'name':...}])
                # - dict plano (p.ej. {'id':..., 'name':...})
                if isinstance(info, dict):
                    # caso 1: dict con ID como clave
                    if all(isinstance(k, str) and isinstance(v, dict) for k, v in info.items()):
                        meta = list(info.values())[0]
                    else:
                        meta = info
                elif isinstance(info, list) and len(info) > 0:
                    meta = info[0]
                else:
                    meta = {}
            
                urls = (meta.get("urls") or {}) if isinstance(meta, dict) else {}
                return {
                    "source": "coinmarketcap",
                    "cmc_id": meta.get("id"),
                    "token_symbol": meta.get("symbol"),
                    "token_name": meta.get("name"),
                    "homepage": (urls.get("website") or [None])[0] if urls else None,
                    "whitepaper_url": (urls.get("technical_doc") or [None])[0] if urls else None,
                    "github_url": (urls.get("source_code") or [None])[0] if urls else None,
                    "twitter_url": (urls.get("twitter") or [None])[0] if urls else None,
                    "reddit_url": (urls.get("reddit") or [None])[0] if urls else None,
                    "telegram_url": (urls.get("chat") or [None])[0] if urls else None,
                    "contract_address": (meta.get("symbol") or [None])[0]
                }

        # 2) map por symbol
        if symbol:
            m = self._map_by_symbol(symbol)
            if m:
                info = self._info_by_id(m["id"])
                urls = (info or {}).get("urls") or {}
                return {
                    "source": "coinmarketcap",
                    "cmc_id": m.get("id"),
                    "token_symbol": m.get("symbol"),
                    "token_name": m.get("name"),
                    "homepage": (urls.get("website") or [None])[0] if urls else None,
                    "whitepaper_url": (urls.get("technical_doc") or [None])[0] if urls else None,
                    "github_url": (urls.get("source_code") or [None])[0] if urls else None,
                    "twitter_url": (urls.get("twitter") or [None])[0] if urls else None,
                    "reddit_url": (urls.get("reddit") or [None])[0] if urls else None,
                    "telegram_url": (urls.get("chat") or [None])[0] if urls else None,
                    "contract_address": (meta.get("symbol") or [None])[0]
                }

        # 3) slug por nombre
        if name:
            slug = to_slug(name)
            m = self._map_by_slug(slug)
            if m:
                info = self._info_by_id(m["id"])
                urls = (info or {}).get("urls") or {}
                return {
                    "source": "coinmarketcap",
                    "cmc_id": m.get("id"),
                    "token_symbol": m.get("symbol"),
                    "token_name": m.get("name"),
                    "homepage": (urls.get("website") or [None])[0] if urls else None,
                    "whitepaper_url": (urls.get("technical_doc") or [None])[0] if urls else None,
                    "github_url": (urls.get("source_code") or [None])[0] if urls else None,
                    "twitter_url": (urls.get("twitter") or [None])[0] if urls else None,
                    "reddit_url": (urls.get("reddit") or [None])[0] if urls else None,
                    "telegram_url": (urls.get("chat") or [None])[0] if urls else None,
                    "contract_address": (meta.get("symbol") or [None])[0]
                }

        # 4) fallback: map_all + fuzzy por nombre (una sola vez cacheado)
        df = self._map_all()
        if df is not None and not df.empty and name:
            nm = normalize_text(name)
            df["sim"] = df["name"].astype(str).map(lambda x: similar(x, nm))
            cand = df.sort_values("sim", ascending=False).head(1)
            if not cand.empty and cand.iloc[0]["sim"] >= 0.85:
                m = cand.iloc[0].to_dict()
                info = self._info_by_id(m["id"])
                urls = (info or {}).get("urls") or {}
                return {
                    "source": "coinmarketcap",
                    "cmc_id": m.get("id"),
                    "token_symbol": m.get("symbol"),
                    "token_name": m.get("name"),
                    "homepage": (urls.get("website") or [None])[0] if urls else None,
                    "whitepaper_url": (urls.get("technical_doc") or [None])[0] if urls else None,
                    "github_url": (urls.get("source_code") or [None])[0] if urls else None,
                    "twitter_url": (urls.get("twitter") or [None])[0] if urls else None,
                    "reddit_url": (urls.get("reddit") or [None])[0] if urls else None,
                    "telegram_url": (urls.get("chat") or [None])[0] if urls else None,
                    "contract_address": (meta.get("symbol") or [None])[0]
                }

        return None

# ===== CoinPaprika =====
class CoinPaprika:
    def __init__(self):
        self.base = "https://api.coinpaprika.com/v1"
        self.headers = {"User-Agent": "TFM-ICO-Enricher/1.1", "Accept":"application/json"}

    def _get(self, path):
        try:
            r = requests.get(f"{self.base}{path}", headers=self.headers, timeout=30)
            if r.status_code != 200:
                print(f"[Paprika] HTTP {r.status_code} path={path} resp={r.text[:160]}")
                time.sleep(SLEEP_PAP)
                return None
            data = r.json()
            time.sleep(SLEEP_PAP)
            return data
        except Exception as e:
            #print(f"[Paprika] error: {e}")
            return None

    def search(self, q: str, limit=10):
        q = quote(q)
        data = self._get(f"/search?q={q}&c=currencies,icos&limit={limit}")
        if not data: return None
        coins = (data or {}).get("currencies") or []  # Paprika separa por tipo
        if not coins:
            coins = (data or {}).get("coins") or []    # algunas respuestas usan 'coins'
        return coins

    def coin(self, coin_id: str):
        return self._get(f"/coins/{coin_id}")

    def resolve(self, symbol: str, name: str):
        symbol = (symbol or "").strip().upper()
        name   = (name or "").strip()
        # 1) buscar por symbol exacto en search
        if symbol:
            hits = self.search(symbol, limit=5) or []
            # exact symbol
            for h in hits:
                if str(h.get("symbol","")).upper() == symbol:
                    det = self.coin(h.get("id"))
                    if not det: continue
                    links = det.get("links") or {}
                    return {
                        "source": "coinpaprika",
                        "paprika_id": h.get("id"),
                        "token_symbol": det.get("symbol"),
                        "token_name": det.get("name"),
                        "homepage": (links.get("website") or [None])[0] if links.get("website") else None,
                        "reddit_url": (links.get("reddit") or [None])[0] if links.get("reddit") else None,
                    }
        # 2) fuzzy por nombre
        if name:
            hits = self.search(name, limit=10) or []
            if hits:
                name_n = normalize_text(name)
                hits.sort(key=lambda h: similar(name_n, normalize_text(h.get("name",""))), reverse=True)
                best = hits[0]
                if similar(name_n, normalize_text(best.get("name",""))) >= 0.85:
                    det = self.coin(best.get("id"))
                    if det:
                        links = det.get("links") or {}
                        return {
                            "source": "coinpaprika",
                            "paprika_id": best.get("id"),
                            "token_symbol": det.get("symbol"),
                            "token_name": det.get("name"),
                            "homepage": (links.get("website") or [None])[0] if links.get("website") else None,
                            "reddit_url": (links.get("reddit") or [None])[0] if links.get("reddit") else None,
                        }
        return None

class FoundICO:
    BASE = "https://foundico.com/api/v1"

    def __init__(self, public_key: Optional[str], private_key: Optional[str]):
        self.pub = public_key
        self.priv = private_key

    def _headers(self, body_dict: Dict[str, Any]) -> Dict[str, str]:
        payload = json.dumps(body_dict, separators=(",", ":"), ensure_ascii=False)
        signature = base64.b64encode(hmac.new(
            key=self.priv.encode("utf-8"),
            msg=payload.encode("utf-8"),
            digestmod=hashlib.sha256
        ).digest()).decode("ascii")
        return {
            "User-Agent": USER_AGENT,
            "Content-Type": "application/json",
            "X-Foundico-Public-Key": self.pub,
            "X-Foundico-Access-Key": signature
        }

    def list_icos(self, page:int=1, status:str="past"):
        if not (self.pub and self.priv): return None
        url = f"{self.BASE}/icos/"
        body = {"page": page, "status": status}
        r = requests.post(url, headers=self._headers(body), data=json.dumps(body), timeout=30)
        if r.status_code != 200: time.sleep(SLEEP_FOUN); return None
        data = r.json()
        time.sleep(SLEEP_FOUN)
        return data

    def profile(self, ico_id:int):
        if not (self.pub and self.priv): return None
        url = f"{self.BASE}/ico/"
        body = {"id": int(ico_id)}
        r = requests.post(url, headers=self._headers(body), data=json.dumps(body), timeout=30)
        if r.status_code != 200: time.sleep(SLEEP_FOUN); return None
        data = r.json()
        time.sleep(SLEEP_FOUN)
        return data

    def search_by_name(self, name: str, max_pages:int=30, status:str="past"):
        if not (self.pub and self.priv): return None
        best, best_sim = None, 0.0
        for page in range(1, max_pages+1):
            lst = self.list_icos(page=page, status=status)
            if not lst or not lst.get("data"): break
            for item in lst["data"]:
                nm = (item.get("main") or {}).get("name") or ""
                sc = similar(nm, name)
                if sc > best_sim:
                    best_sim, best = sc, item
            if best_sim >= 0.9: break
        if not best: return None
        prof = self.profile(int(best["id"]))
        if not prof or not prof.get("data"): return None
        d = prof["data"]
        main = d.get("main") or {}
        links = d.get("links") or {}
        finance = d.get("finance") or {}
        return {
            "source": "foundico",
            "foundico_id": d.get("id"),
            "token_symbol": finance.get("ticker"),
            "token_name": main.get("name"),
            "homepage": links.get("website"),
            "whitepaper_url": links.get("whitepaper"),
            "token_type": finance.get("token_type"),
            "tokens_for_sale": to_int(finance.get("tokens_for_sale")),
            "token_price_usd": float(finance.get("token_price")) if finance.get("token_price") not in [None,""] else None,
            "soft_cap_usd": parse_money_like(finance.get("soft_cap")),
            "hard_cap_usd": parse_money_like(finance.get("hard_cap")),
            "accepted_currencies": None,
            "kyc": boolify(main.get("kyc")),
            "whitelist": boolify(main.get("whitelist")),
            "jurisdiction": main.get("location"),
            "category": main.get("category"),
            "has_github": None,
            "rating": main.get("ico_score") and float(main.get("ico_score")),
            "whitepaper_available": 1 if links.get("whitepaper") else None,
            "roadmap_available": 1 if d.get("roadmap") else None,
            "team_size": len(d.get("team") or []),
        }

# %%
# %% Lógica de enriquecimiento por fila

def enrich_row(
    row: pd.Series,
    cg: CoinGecko,
    cmc: CoinMarketCap,
    pap: CoinPaprika,
    fou: FoundICO,
    exante_only: bool,
    overwrite_missing: bool,
    cache: Dict[str, Any],
    foundico_max_pages: int = 30,
) -> Dict[str, Any]:
    """
    Devuelve dict {col: nuevo_valor} para completar en la fila.
    """
    name = normalize_text(row.get("name_std"))
    symbol = normalize_text(row.get("symbol_std")).upper()

    # cache key
    ck = f"resolve::{symbol or '_'}::{name or '_'}"
    if ck in cache:
        hits = cache[ck]
    else:
        hits = []
        try:
            fou_need = not symbol or symbol == ""
            # FoundICO primero si falta symbol o no hay nada
            # if fou_need and (FOUN_PUB and FOUN_PRIV):
            #     fou_hit = fou.search_by_name(name or symbol, max_pages=foundico_max_pages, status="past")
            #     if fou_hit: hits.append(fou_hit)
        except Exception:
            pass
        try:
            if symbol or name:
                cg_hit = cg.resolve(symbol=symbol, name=name)
                if cg_hit:
                    #print(f'CoinGecko: {cg_hit}')
                    hits.append(cg_hit)
                else:
                    print('Nada en CoinGecko')
        except Exception as e:
            #print(f'Error CoinGecko: {e}')
            pass
        try:
            cmc_hit = cmc.resolve(symbol=symbol, name=name) if CMC_API_KEY else None
            if cmc_hit: 
                #print(f'CoinMarketCap: {cmc_hit}')
                hits.append(cmc_hit)
            else:
                print('Nada en CoinMarketCap')
        except Exception as e:
            #print(f'Error CoinMarketCap: {e}')
            pass
            
        # try:
        #     pap_hit = pap.resolve(symbol=symbol, name=name)
        #     if pap_hit: 
        #         print(f'CoinPaprika: {pap_hit}')
        #         hits.append(pap_hit)
        #     else:
        #         print('Nada en CoinPaprika')
        # except Exception as e:
        #     #print(f'Error CoinPaprika: {e}')
        #     pass
            
        # FoundICO al final si todavía no hay nada útil
        # if not hits and (FOUN_PUB and FOUN_PRIV):
         #    try:
          #       fou_hit = fou.search_by_name(name or symbol, max_pages=foundico_max_pages, status="past")
           #      if fou_hit: 
            #         print(f'FoundICO: {fou_hit}')
             #        hits.append(fou_hit)
              #   else:
               #      print('Nada en FoundICO')
            # except Exception as e:
             #    #print(f'Error FoundICO: {e}')
              #   pass

        cache[ck] = hits

    # Consolidación por prioridad de tokenomics de ICO
    priority = ["foundico", "coingecko", "coinmarketcap", "coinpaprika"]
    best = {}
    for src in priority:
        for h in hits:
            if h.get("source") == src:
                for k, v in h.items():
                    if v not in [None, "", [], {}]:
                        best.setdefault(k, v)

    # Campos ex-ante a completar
    exante_fields = [
        "token_symbol","token_name","homepage","whitepaper_url","github_url","twitter_url","telegram_url","reddit_url",
        "market_cap_rank", "sentiment_votes_up_percentage", "sentiment_votes_down_percentage", "contract_address", "has_github"
        #"token_type","tokens_for_sale","token_price_usd","soft_cap_usd","hard_cap_usd","accepted_currencies",
        #"kyc","whitelist","jurisdiction","category","team_size","has_github","roadmap_available","whitepaper_available","rating"
    ]
    fields = exante_fields if exante_only else exante_fields  # hook para futuro

    patch = {}
    for f in fields:
        cur = row.get(f)
        new = best.get(f)
        if overwrite_missing:
            if (cur in [None, "", np.nan]) and (new not in [None, "", np.nan]):
                patch[f] = new
        else:
            if (cur in [None, "", np.nan]) and (new not in [None, "", np.nan]):
                patch[f] = new

    # Si falta symbol_std y obtuvimos token_symbol → rellenar
    if (row.get("symbol_std") in [None, "", np.nan]) and best.get("token_symbol"):
        patch["symbol_std"] = str(best["token_symbol"]).upper()

    return patch

# %%
# %% Proceso: carga dataset, enriquece, rellena y guarda el nuevo dataset

# Instanciar clientes API
cg  = CoinGecko(api_key=CG_API_KEY)
cmc = CoinMarketCap(api_key=CMC_API_KEY)
pap = CoinPaprika()
fou = FoundICO(public_key=FOUN_PUB, private_key=FOUN_PRIV)

# Cargar dataset
df = pd.read_csv(IN_PATH)
#df = df.sample(10)
if "name_std" not in df.columns and "symbol_std" not in df.columns:
    raise RuntimeError("Se requieren columnas 'name_std' y/o 'symbol_std'.")

# Asegurar columnas destino (si no existen)
target_cols = [
    "token_symbol","token_name","homepage","whitepaper_url","github_url","twitter_url","telegram_url","reddit_url",
    "token_type","tokens_for_sale","token_price_usd","soft_cap_usd","hard_cap_usd","accepted_currencies",
    "kyc","whitelist","jurisdiction","category","team_size","has_github","roadmap_available","whitepaper_available","rating"
]
for c in target_cols:
    if c not in df.columns:
        df[c] = np.nan

#data = [{"name_std": "Binance","symbol_std": "BNB"}]
#df = pd.DataFrame(data)
#df = pd.DataFrame(data)
#df.append(data)
#df["name_std"] = "Bitcoin"
#df["symbol_std"] = "BTC"

cache = load_cache(CACHE_PATH)
MAX_ROWS=0
n = len(df) if MAX_ROWS == 0 else min(MAX_ROWS, len(df))
updates = 0
t0 = time.time()
print(n)
cg_cmc_findings = []

for i in range(n):
    row = df.iloc[i]
    print(f'{row["name_std"]} - {row["symbol_std"]}')
    patch = enrich_row(
        row=row,
        cg=cg, cmc=cmc, pap=pap, fou=fou,
        exante_only=EXANTE_ONLY,
        overwrite_missing=OVERWRITE_MISSING,
        cache=cache,
        foundico_max_pages=FOUN_FIND_MAX_PAGES
    )
    if patch:
        for k, v in patch.items():
            print(f"Hay patch: {k} - {v}")
            df.at[row.name, k] = v
        updates += 1
        cg_cmc_findings.append(patch)

    if (i+1) % 50 == 0:
        save_cache(cache, CACHE_PATH)
        print(f"[{i+1}/{n}] guardado cache...")

df_cg_cmc = pd.DataFrame(cg_cmc_findings)
df_cg_cmc_PATH = "../final/df_cg_cmc.csv"
df_cg_cmc.to_csv(df_cg_cmc_PATH, index=False)
save_cache(cache, CACHE_PATH)

# Post: normalizar tipos básicos
for bcol in ["kyc","whitelist","whitepaper_available","roadmap_available","has_github"]:
    if bcol in df.columns:
        df[bcol] = df[bcol].apply(lambda x: boolify(x) if pd.notna(x) else x)

for mcol in ["soft_cap_usd","hard_cap_usd","token_price_usd","tokens_for_sale","team_size"]:
    if mcol in df.columns:
        df[mcol] = pd.to_numeric(df[mcol], errors="coerce")

df.to_csv(OUT_PATH, index=False)
dt = time.time() - t0

print(f"✅ Guardado enriquecido: {OUT_PATH}")
print(f"Filas procesadas: {n} | Filas con cambios: {updates} | Tiempo: {dt:.1f}s")

# Resumen de cobertura
filled = []
for c in target_cols:
    if c in df.columns:
        pct = (df[c].notna() & (df[c].astype(str).str.strip() != "")).mean()*100
        filled.append((c, round(pct,2)))
filled.sort(key=lambda x: -x[1])

print("\nCobertura (no-nulos, %):")
for c, p in filled:
    print(f"{c:24s} {p:6.2f}%")
# Out:
# 5430
# baby gamium - BABYGMM
# Nada en CoinGecko
# Nada en CoinMarketCap
# e-commerce of global consulting business - BEEPOWER
# Nada en CoinGecko
# Nada en CoinMarketCap
# pepebinky - BEKY
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitdoge - BITDOGE
# Nada en CoinGecko
# Nada en CoinMarketCap
# bankii - BKNY
# Nada en CoinGecko
# Nada en CoinMarketCap
# bold - BOLD
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcoin bsc - BTCBSC
# Nada en CoinGecko
# bitcoincopy - BTCC
# Nada en CoinMarketCap
# bitcoin minetrix - BTCMTX
# Nada en CoinGecko
# Nada en CoinMarketCap
# c+charge - CCHG
# Nada en CoinGecko
# Hay patch: contract_address - C
# $cvpad - CVPAD
# Nada en CoinGecko
# Nada en CoinMarketCap
# deboard - DEVAX
# Nada en CoinGecko
# Nada en CoinMarketCap
# dogeverse - DOGEVERSE
# Nada en CoinGecko
# Hay patch: contract_address - D
# freedum fighters - DUM
# Nada en CoinGecko
# Nada en CoinMarketCap
# $ecom - ECOM
# Nada en CoinGecko
# Hay patch: contract_address - E
# ecoterra - ECOTERRA
# Nada en CoinGecko
# Hay patch: contract_address - E
# eywa - EYWA
# Nada en CoinGecko
# Hay patch: contract_address - E
# fayre - FAYRE
# Nada en CoinGecko
# Hay patch: contract_address - F
# fightout - FGHT
# Nada en CoinGecko
# Hay patch: contract_address - F
# furgpt - FGPT
# Nada en CoinGecko
# Hay patch: contract_address - F
# skaflic - FLIC
# Nada en CoinGecko
# Nada en CoinMarketCap
# flockerz - FLOCK
# Nada en CoinGecko
# Hay patch: contract_address - F
# hedge compass - HCS
# Nada en CoinGecko
# Hay patch: contract_address - H
# helper world - HLPR
# Nada en CoinGecko
# Hay patch: contract_address - H
# $honey - HONEY
# Nada en CoinGecko
# Hay patch: contract_address - H
# huzzl - HUZZL
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoinhyper - HYPER
# Nada en CoinGecko
# Hay patch: contract_address - H
# imagen network - IMAGE
# Nada en CoinGecko
# Nada en CoinMarketCap
# tonlancer - LCR
# Nada en CoinGecko
# Nada en CoinMarketCap
# launchpad xyz - LPX
# Nada en CoinGecko
# Nada en CoinMarketCap
# scapesmania - MANIA
# Nada en CoinGecko
# Nada en CoinMarketCap
# memebet - MEMEBET
# Nada en CoinGecko
# Nada en CoinMarketCap
# minionverse tower defense trading card game - MIVRS
# Nada en CoinGecko
# Hay patch: contract_address - M
# naruto - NARUTO
# Hay patch: contract_address - N
# nekoin protocol - NEK
# Nada en CoinGecko
# optitoken - OPTI
# Nada en CoinGecko
# Hay patch: contract_address - O
# inmusik - OUND
# Nada en CoinGecko
# Nada en CoinMarketCap
# pepe unchained - PEPU
# Nada en CoinGecko
# Hay patch: contract_address - P
# plaix - PLAIX
# Nada en CoinGecko
# Nada en CoinMarketCap
# truepnl - PNL
# Nada en CoinGecko
# Nada en CoinMarketCap
# poodlinu - POODL
# Nada en CoinGecko
# Hay patch: contract_address - P
# pepegod - PPGOD
# Nada en CoinGecko
# Nada en CoinMarketCap
# therapy dog coin - RXDOG
# Nada en CoinGecko
# Nada en CoinMarketCap
# satoshidex.ai - SDEX
# Nada en CoinGecko
# Hay patch: contract_address - S
# snorter - SNORT
# Nada en CoinGecko
# Hay patch: contract_address - S
# spotshot - SPT
# Nada en CoinGecko
# Hay patch: contract_address - S
# stakelayer - STAKELAYER
# Nada en CoinGecko
# Nada en CoinMarketCap
# crypto all stars - STARS
# Nada en CoinGecko
# Hay patch: contract_address - S
# stabble - STB
# Nada en CoinGecko
# Hay patch: contract_address - S
# charonium® - STYX
# Nada en CoinGecko
# Nada en CoinMarketCap
# [50/5430] guardado cache...
# solana vm - SVM
# Nada en CoinGecko
# Hay patch: contract_address - S
# token tails - TAILS
# Nada en CoinGecko
# Nada en CoinMarketCap
# thoon - THOON
# Nada en CoinGecko
# Nada en CoinMarketCap
# tiga coin - TIGA
# Nada en CoinGecko
# Nada en CoinMarketCap
# usagi protocol - USAGI
# Nada en CoinGecko
# Nada en CoinMarketCap
# wall street memes - WSM
# Hay patch: contract_address - W
# arcana network - XAR
# Hay patch: contract_address - X
# zesh - ZESH
# Nada en CoinGecko
# Nada en CoinMarketCap
# itoassendelft - (WALNUT)
# Nada en CoinGecko
# Nada en CoinMarketCap
# hirego - 0
# Nada en CoinGecko
# bitcoin dogs club - 0DOG
# Nada en CoinGecko
# Hay patch: contract_address - 0
# blockchain biometric spectrum - 1
# Nada en CoinGecko
# Hay patch: contract_address - 1
# 108token - 108T
# Nada en CoinGecko
# Nada en CoinMarketCap
# texeract network - 1111111111
# Nada en CoinGecko
# safari swap - 18
# Nada en CoinGecko
# Nada en CoinMarketCap
# 1ai revolution - 1AI
# Nada en CoinGecko
# Hay patch: contract_address - 1
# 1apayment - 1AP
# Nada en CoinGecko
# Nada en CoinMarketCap
# 1kcoin - 1KCOIN
# Nada en CoinGecko
# firstblood - 1ST
# Nada en CoinGecko
# Hay patch: contract_address - 1
# 1teraton - 1TT
# Nada en CoinGecko
# Nada en CoinMarketCap
# 2022token - 2022TOKEN
# Nada en CoinGecko
# Nada en CoinMarketCap
# weeom software - 248013
# Nada en CoinGecko
# Nada en CoinMarketCap
# carati - 24CAR
# Nada en CoinGecko
# 27v - 27V
# Nada en CoinGecko
# Nada en CoinMarketCap
# 2gether - 2GT
# Nada en CoinGecko
# Nada en CoinMarketCap
# 2local - 2LC
# Nada en CoinGecko
# 2paccoin - 2PAC
# Nada en CoinGecko
# Nada en CoinMarketCap
# 3ccoin - 3CCOIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# 3dax - 3DAX
# Nada en CoinGecko
# Nada en CoinMarketCap
# districts - 3DC
# Nada en CoinGecko
# Hay patch: contract_address - 3
# 3dp token - 3DP
# Nada en CoinGecko
# Nada en CoinMarketCap
# 3d-token - 3DT
# Nada en CoinGecko
# Nada en CoinMarketCap
# 3dchain - 3XD
# Nada en CoinGecko
# 4artechnologies - 4ART
# Nada en CoinGecko
# Hay patch: contract_address - 4
# mybtcfx - 4XBIT
# Nada en CoinGecko
# Nada en CoinMarketCap
# 5th scape - 5SCAPE
# Nada en CoinGecko
# Nada en CoinMarketCap
# 777.bingo - 777
# Nada en CoinGecko
# Hay patch: contract_address - 7
# graphentech - 77G
# Nada en CoinGecko
# Nada en CoinMarketCap
# 7-24 fun - 7FF
# Nada en CoinGecko
# Nada en CoinMarketCap
# 7ype - 7YPE
# Nada en CoinGecko
# Nada en CoinMarketCap
# octaneum - 8AN
# Nada en CoinGecko
# Nada en CoinMarketCap
# 8circuitstudios - 8BT
# Nada en CoinGecko
# Nada en CoinMarketCap
# gig9 - 9COIN
# Nada en CoinGecko
# Hay patch: contract_address - 9
# alpha investing - A
# Nada en CoinGecko
# Nada en CoinMarketCap
# apollo18 - A18
# Nada en CoinGecko
# Nada en CoinMarketCap
# stex exchange a2a - A2A
# Nada en CoinGecko
# Nada en CoinMarketCap
# a4r fitness lifestyle token - A4R
# Nada en CoinGecko
# Nada en CoinMarketCap
# aamicoin - AAMI
# Nada en CoinGecko
# Nada en CoinMarketCap
# аassio - AAS
# Nada en CoinGecko
# Nada en CoinMarketCap
# antibank - AB
# Hay patch: contract_address - A
# [100/5430] guardado cache...
# alibabacoin - ABBC
# Hay patch: contract_address - A
# astro bux coin - ABCD
# Nada en CoinGecko
# Hay patch: contract_address - A
# abacasxchange - ABCS
# Nada en CoinGecko
# Nada en CoinMarketCap
# abele - ABELE
# Nada en CoinGecko
# abiocoin - ABI
# Nada en CoinGecko
# Hay patch: contract_address - A
# aibittech - ABI
# Nada en CoinGecko
# Hay patch: contract_address - A
# airbloc - ABL
# Nada en CoinGecko
# Hay patch: contract_address - A
# abmcoin - ABM
# Nada en CoinGecko
# abeona - ABN
# Nada en CoinGecko
# Hay patch: contract_address - A
# albino - ABO
# Nada en CoinGecko
# Hay patch: contract_address - A
# astrobonk - ABONK
# Nada en CoinGecko
# Nada en CoinMarketCap
# autobay - ABX
# Nada en CoinGecko
# Hay patch: contract_address - A
# autobay - ABX
# Hay patch: contract_address - A
# autobay - ABX
# Hay patch: contract_address - A
# autobay - ABX
# Hay patch: contract_address - A
# the abyss - ABYSS
# Nada en CoinGecko
# Hay patch: contract_address - A
# academic coin - ACA
# Nada en CoinGecko
# Hay patch: contract_address - A
# academic coin - ACA
# Hay patch: contract_address - A
# metacces - ACCESS
# Nada en CoinGecko
# Nada en CoinMarketCap
# accommodation coin - ACCO
# Nada en CoinGecko
# Nada en CoinMarketCap
# anonymous crypto casino platform - ACCP
# Nada en CoinGecko
# Nada en CoinMarketCap
# acadex network - ACDX
# Nada en CoinGecko
# Hay patch: contract_address - A
# tokenstars ace - ACE
# Nada en CoinGecko
# Hay patch: contract_address - A
# etheracespeculationplatform - ACED
# Nada en CoinGecko
# Hay patch: contract_address - A
# artcoin - ACF
# Nada en CoinGecko
# achievecoin - ACH
# Nada en CoinGecko
# Nada en CoinMarketCap
# arc-iris - ACI
# Nada en CoinGecko
# Nada en CoinMarketCap
# arciris - ACI
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockademia - ACI
# Nada en CoinGecko
# Nada en CoinMarketCap
# aclyd - ACLYD
# Nada en CoinGecko
# Nada en CoinMarketCap
# advanced miners - ACM
# Hay patch: contract_address - A
# advanced miners - ACM
# Hay patch: contract_address - A
# acm - ACM
# Hay patch: contract_address - A
# acm - ACM
# Hay patch: contract_address - A
# armor ceramics - ACR
# Nada en CoinGecko
# Hay patch: contract_address - A
# acred - ACRE
# Nada en CoinGecko
# Hay patch: contract_address - A
# acetcoin - ACT
# Nada en CoinGecko
# Hay patch: contract_address - A
# aceticprotocol - ACT
# Nada en CoinGecko
# Hay patch: contract_address - A
# acta finance - ACTA
# Nada en CoinGecko
# Hay patch: contract_address - A
# activity - ACTIVITY
# Nada en CoinGecko
# Nada en CoinMarketCap
# actioncoin - ACTN
# Nada en CoinGecko
# Hay patch: contract_address - A
# acmenetwork - ACX
# Nada en CoinGecko
# Hay patch: contract_address - A
# adab solutions - ADAB
# Nada en CoinGecko
# Hay patch: contract_address - A
# adbank - ADB
# Nada en CoinGecko
# Hay patch: contract_address - A
# adblurb - ADBL
# Nada en CoinGecko
# Nada en CoinMarketCap
# adenium - ADE
# Nada en CoinGecko
# Hay patch: contract_address - A
# adgonos - ADG
# Nada en CoinGecko
# Hay patch: contract_address - A
# adhive - ADH
# Nada en CoinGecko
# Hay patch: contract_address - A
# aditus - ADI
# Nada en CoinGecko
# Hay patch: contract_address - A
# adelphoi - ADL
# Nada en CoinGecko
# Hay patch: contract_address - A
# [150/5430] guardado cache...
# adamant messenger - ADM
# Nada en CoinGecko
# Hay patch: contract_address - A
# adosia - ADO
# Nada en CoinGecko
# Hay patch: contract_address - A
# adonx - ADONX
# Nada en CoinGecko
# Nada en CoinMarketCap
# adshares - ADST
# Nada en CoinGecko
# adtoken - ADT
# Nada en CoinGecko
# Hay patch: contract_address - A
# adult x token - ADUX
# Nada en CoinGecko
# Nada en CoinMarketCap
# antiderivative - ADVT
# Nada en CoinGecko
# adaxum - ADX
# Nada en CoinGecko
# Hay patch: contract_address - A
# aeternity - AE
# Nada en CoinGecko
# Hay patch: contract_address - A
# airgeadcoin - AED
# Nada en CoinGecko
# aen token - AEN
# Hay patch: contract_address - A
# aenco - AEN
# Hay patch: contract_address - A
# aen - AENT
# Nada en CoinGecko
# aeryus - AER
# Nada en CoinGecko
# Hay patch: contract_address - A
# artisaesevolution - AES
# Nada en CoinGecko
# Hay patch: contract_address - A
# aetherx - AETX
# Nada en CoinGecko
# allforcrypto - AFCT
# Nada en CoinGecko
# Nada en CoinMarketCap
# affiliatecoin - AFLC
# Nada en CoinGecko
# Nada en CoinMarketCap
# allforonebusiness - AFO
# Nada en CoinGecko
# Hay patch: contract_address - A
# afrochain - AFR
# Nada en CoinGecko
# Hay patch: contract_address - A
# afrolis - AFR
# Nada en CoinGecko
# Hay patch: contract_address - A
# afsecurity - AFS
# Nada en CoinGecko
# Nada en CoinMarketCap
# airforce mining - AFX
# Nada en CoinGecko
# Hay patch: contract_address - A
# agacoin - AGACOIN
# Nada en CoinGecko
# again project - AGAIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# arqutegas - AGAS
# Nada en CoinGecko
# Nada en CoinMarketCap
# delysium - AGI
# Nada en CoinGecko
# singularitynet - AGI
# Nada en CoinGecko
# agii - AGII
# Nada en CoinGecko
# Nada en CoinMarketCap
# agrolot - AGLT
# Nada en CoinGecko
# argonium - AGNM
# Nada en CoinGecko
# the agora - AGO
# Hay patch: contract_address - A
# agrivita - AGR
# Nada en CoinGecko
# Nada en CoinMarketCap
# agrichain - AGRI
# Nada en CoinGecko
# Hay patch: contract_address - A
# agric - AGRICC
# Nada en CoinGecko
# Nada en CoinMarketCap
# agritoken - AGRIT
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitagro - AGRO
# Nada en CoinGecko
# Hay patch: contract_address - A
# sol-invictus - AGS
# Nada en CoinGecko
# Hay patch: contract_address - A
# agate - AGT
# Nada en CoinGecko
# Hay patch: contract_address - A
# agifttoken - AGT
# Nada en CoinGecko
# Hay patch: contract_address - A
# agavecoin - AGVC
# Nada en CoinGecko
# Hay patch: contract_address - A
# ahoolee - AHT
# Nada en CoinGecko
# Hay patch: contract_address - A
# aibank global - AIB
# Nada en CoinGecko
# Hay patch: contract_address - A
# akaiito - AIC
# Nada en CoinGecko
# Hay patch: contract_address - A
# akaiito - AIC
# Hay patch: contract_address - A
# akaiito - AIC
# Hay patch: contract_address - A
# aitheon - AIC
# Nada en CoinGecko
# Hay patch: contract_address - A
# aitheon - AIC
# Hay patch: contract_address - A
# aitheon - AIC
# Hay patch: contract_address - A
# ai crypto - AIC
# Nada en CoinGecko
# Hay patch: contract_address - A
# [200/5430] guardado cache...
# ai crypto - AIC
# Hay patch: contract_address - A
# ai crypto - AIC
# Hay patch: contract_address - A
# aida service - AID
# Nada en CoinGecko
# Hay patch: contract_address - A
# aida service - AID
# Hay patch: contract_address - A
# aida service - AID
# Hay patch: contract_address - A
# aida service - AID
# Hay patch: contract_address - A
# aidus - AID
# Nada en CoinGecko
# Hay patch: contract_address - A
# aidus - AID
# Hay patch: contract_address - A
# aidus - AID
# Hay patch: contract_address - A
# aidus - AID
# Hay patch: contract_address - A
# artificial intelligence defi - AID
# Nada en CoinGecko
# Hay patch: contract_address - A
# artificial intelligence defi - AID
# Hay patch: contract_address - A
# artificial intelligence defi - AID
# Hay patch: contract_address - A
# artificial intelligence defi - AID
# Hay patch: contract_address - A
# aigcoin - AIGC
# Nada en CoinGecko
# aigo protocol - AIGO
# Nada en CoinGecko
# aimedis - AIM
# Nada en CoinGecko
# Nada en CoinMarketCap
# aiom - AIOM
# Nada en CoinGecko
# aiopinion - AIOP
# Nada en CoinGecko
# Nada en CoinMarketCap
# advanced initial offering - AIOT
# Hay patch: contract_address - A
# air wallet - AIR
# Nada en CoinGecko
# Hay patch: contract_address - A
# air wallet - AIR
# Hay patch: contract_address - A
# airen - AIRE
# Nada en CoinGecko
# Nada en CoinMarketCap
# tokenaire - AIRE
# Nada en CoinGecko
# Nada en CoinMarketCap
# aircraft - AIRT
# Nada en CoinGecko
# Hay patch: contract_address - A
# airexe - AIRX
# Nada en CoinGecko
# Hay patch: contract_address - A
# ais - AIS
# Nada en CoinGecko
# Hay patch: contract_address - A
# aisicoin - AISI
# Nada en CoinGecko
# aithereum - AITH
# Nada en CoinGecko
# aitn network - AITN
# Nada en CoinGecko
# Hay patch: contract_address - A
# aitrading - AITT
# Nada en CoinGecko
# Nada en CoinMarketCap
# aivia - AIV
# Nada en CoinGecko
# Hay patch: contract_address - A
# aigang - AIX
# Nada en CoinGecko
# Hay patch: contract_address - A
# artwook - AKC
# Nada en CoinGecko
# Hay patch: contract_address - A
# anuutech - AKEY
# Nada en CoinGecko
# Nada en CoinMarketCap
# akronix - AKRON
# Nada en CoinGecko
# Nada en CoinMarketCap
# aktie social - AKT
# Nada en CoinGecko
# Hay patch: contract_address - A
# aktie social - AKT
# Hay patch: contract_address - A
# aktio coin - AKTIO
# Nada en CoinGecko
# Hay patch: contract_address - A
# alpay - AL
# Nada en CoinGecko
# Hay patch: contract_address - A
# adventure league - AL
# Nada en CoinGecko
# Hay patch: contract_address - A
# alchemybyte - ALB
# Nada en CoinGecko
# Nada en CoinMarketCap
# allbebet - ALB
# Nada en CoinGecko
# Nada en CoinMarketCap
# alicoincash - ALC
# Nada en CoinGecko
# Nada en CoinMarketCap
# aligatocoin - ALC
# Nada en CoinGecko
# Nada en CoinMarketCap
# allcare - ALCR
# Nada en CoinGecko
# Nada en CoinMarketCap
# alehub - ALE
# Hay patch: contract_address - A
# alea - ALEA
# aleef coin - ALEEF
# Nada en CoinGecko
# Nada en CoinMarketCap
# alfa - ALFA
# Nada en CoinGecko
# Hay patch: contract_address - A
# [250/5430] guardado cache...
# algory project - ALG
# Nada en CoinGecko
# Hay patch: contract_address - A
# leap with alice - ALICE
# Nada en CoinGecko
# Hay patch: contract_address - A
# alink ai - ALINK
# Nada en CoinGecko
# Hay patch: contract_address - A
# alis - ALIS
# Nada en CoinGecko
# Hay patch: contract_address - A
# aliveme - ALIVE
# Nada en CoinGecko
# Nada en CoinMarketCap
# allsporter - ALL
# Nada en CoinGecko
# Hay patch: contract_address - A
# allbi tokens - ALLBI
# Nada en CoinGecko
# Nada en CoinMarketCap
# all mall - ALLM
# Nada en CoinGecko
# Nada en CoinMarketCap
# all of art - ALLOFART
# Nada en CoinGecko
# Nada en CoinMarketCap
# alloy - ALLOY
# Nada en CoinGecko
# alloy project - ALLOY
# Nada en CoinGecko
# alemio - ALM
# Nada en CoinGecko
# Hay patch: contract_address - A
# alpencoin - ALP
# Nada en CoinGecko
# Hay patch: contract_address - A
# alphaplay - ALPH
# Nada en CoinGecko
# Hay patch: contract_address - A
# akilos - ALS
# Nada en CoinGecko
# Hay patch: contract_address - A
# akilos - ALS
# Hay patch: contract_address - A
# alsonft e-commerce marketplace - ALSONFT
# Nada en CoinGecko
# Nada en CoinMarketCap
# alt.estate - ALT
# Nada en CoinGecko
# Nada en CoinMarketCap
# alatyr - ALTR
# Nada en CoinGecko
# Nada en CoinMarketCap
# alttex - ALTX
# Nada en CoinGecko
# lux ant digital bank - ALUX
# Nada en CoinGecko
# Nada en CoinMarketCap
# alux bank - ALUX
# Nada en CoinGecko
# Nada en CoinMarketCap
# alax - ALX
# Hay patch: contract_address - A
# alaxio - ALX
# Hay patch: contract_address - A
# ambrosus - AMB
# Hay patch: contract_address - A
# amberport - AMBR
# Nada en CoinGecko
# Hay patch: contract_address - A
# ambit - AMBT
# Nada en CoinGecko
# amchart - AMC
# Nada en CoinGecko
# Hay patch: contract_address - A
# amsterex - AME
# Nada en CoinGecko
# Hay patch: contract_address - A
# amfi by amdao - AMFI
# Nada en CoinGecko
# Nada en CoinMarketCap
# arena match - AMG
# Nada en CoinGecko
# Hay patch: contract_address - A
# amicorum - AMI
# Nada en CoinGecko
# Hay patch: contract_address - A
# arraymonk - AMK
# Nada en CoinGecko
# Nada en CoinMarketCap
# micromoney - AMM
# Nada en CoinGecko
# Hay patch: contract_address - A
# ammbr - AMMBR
# Nada en CoinGecko
# Nada en CoinMarketCap
# amon - AMN
# Nada en CoinGecko
# Hay patch: contract_address - A
# amorito - AMO
# Nada en CoinGecko
# Hay patch: contract_address - A
# amo coin - AMO
# Nada en CoinGecko
# Hay patch: contract_address - A
# synereo - AMP
# Nada en CoinGecko
# Hay patch: contract_address - A
# ampleforth - AMPL
# Nada en CoinGecko
# Hay patch: contract_address - A
# ampleforth - AMPL
# Hay patch: contract_address - A
# ammeris - AMRS
# Nada en CoinGecko
# Nada en CoinMarketCap
# marsterminal - AMT
# Nada en CoinGecko
# Hay patch: contract_address - A
# anubis - ANB
# Nada en CoinGecko
# Hay patch: contract_address - A
# baappay - ANC
# Nada en CoinGecko
# Hay patch: contract_address - A
# antidepress project - ANDT
# Nada en CoinGecko
# Nada en CoinMarketCap
# angrytoken - ANG
# Nada en CoinGecko
# Nada en CoinMarketCap
# angel pay token - ANG
# Nada en CoinGecko
# Nada en CoinMarketCap
# angelpay - ANG
# Nada en CoinGecko
# Nada en CoinMarketCap
# crowd for angels - ANGEL
# Nada en CoinGecko
# Nada en CoinMarketCap
# [300/5430] guardado cache...
# crypto angel - ANGEL
# Nada en CoinGecko
# Nada en CoinMarketCap
# anires - ANIRES
# Nada en CoinGecko
# Nada en CoinMarketCap
# airchain network - ANK
# Hay patch: contract_address - A
# beankh - ANKH
# Nada en CoinGecko
# Nada en CoinMarketCap
# animal concerts - ANML
# Nada en CoinGecko
# Hay patch: contract_address - A
# agentnotneeded - ANN
# Nada en CoinGecko
# Hay patch: contract_address - A
# anna - ANNA
# Nada en CoinGecko
# anonymous - ANON
# Nada en CoinGecko
# Hay patch: contract_address - A
# axonswap protocol - ANP
# Nada en CoinGecko
# Nada en CoinMarketCap
# cryptoassetrating - ANSA
# Nada en CoinGecko
# Nada en CoinMarketCap
# aragon - ANT
# Nada en CoinGecko
# Hay patch: contract_address - A
# animal nation - ANTK
# Nada en CoinGecko
# Nada en CoinMarketCap
# alphanu - ANU
# Nada en CoinGecko
# Nada en CoinMarketCap
# coinanx - ANX
# Nada en CoinGecko
# Hay patch: contract_address - A
# astra network - ANX
# Nada en CoinGecko
# Hay patch: contract_address - A
# art on chain - AOC
# Nada en CoinGecko
# Hay patch: contract_address - A
# astronautoceanprotocol - AOP
# Nada en CoinGecko
# Hay patch: contract_address - A
# aropa - APA
# Nada en CoinGecko
# Hay patch: contract_address - A
# astoria - APC
# Nada en CoinGecko
# Hay patch: contract_address - A
# apg coin - APG
# Nada en CoinGecko
# Hay patch: contract_address - A
# api3 - API3
# Nada en CoinGecko
# Hay patch: contract_address - A
# apis - APIS
# Nada en CoinGecko
# Nada en CoinMarketCap
# apisbeechain - APIS
# Nada en CoinGecko
# Nada en CoinMarketCap
# altplanet - APL
# Nada en CoinGecko
# Nada en CoinMarketCap
# apollo septem - APO
# Nada en CoinGecko
# Nada en CoinMarketCap
# apollo septem - APO
# apollo septem - APO
# apo finance - APO
# Nada en CoinGecko
# apo finance - APO
# apo finance - APO
# apollon - APO
# Nada en CoinGecko
# apollon - APO
# apollon - APO
# airpod - APOD
# Nada en CoinMarketCap
# appcoins - APPC
# Nada en CoinGecko
# Hay patch: contract_address - A
# appreciate coin - APPR
# Nada en CoinGecko
# Nada en CoinMarketCap
# artpro - APT
# Nada en CoinGecko
# Hay patch: contract_address - A
# apollox - APXT
# Nada en CoinGecko
# alprockz - APZ
# Nada en CoinGecko
# Nada en CoinMarketCap
# aquest - AQU
# Nada en CoinGecko
# Hay patch: contract_address - A
# aqua - AQUA
# Nada en CoinGecko
# Hay patch: contract_address - A
# sansox - AQUA
# Nada en CoinGecko
# Hay patch: contract_address - A
# aqua intelligence - AQX
# Nada en CoinGecko
# Nada en CoinMarketCap
# arcadia - AR2
# Nada en CoinGecko
# Nada en CoinMarketCap
# araw token - ARAW
# Nada en CoinGecko
# Nada en CoinMarketCap
# arbitraging - ARB
# Nada en CoinGecko
# Hay patch: contract_address - A
# arbitrum - ARB
# Nada en CoinGecko
# Hay patch: contract_address - A
# arbi - ARBI
# Nada en CoinGecko
# Hay patch: contract_address - A
# arbitai - ARBIT
# Nada en CoinGecko
# Nada en CoinMarketCap
# arbitium - ARBITIUM
# Nada en CoinGecko
# Nada en CoinMarketCap
# [350/5430] guardado cache...
# archain - ARC
# Nada en CoinGecko
# Hay patch: contract_address - A
# arch crypton game - ARCG
# Nada en CoinGecko
# Hay patch: contract_address - A
# archway - ARCH
# Nada en CoinGecko
# Nada en CoinMarketCap
# arch crypton - ARCHC
# Nada en CoinGecko
# Nada en CoinMarketCap
# arcona - ARCONA
# Nada en CoinGecko
# ava area - AREA
# Nada en CoinGecko
# argo reality - ARGO
# Hay patch: contract_address - A
# bartvault - ARISTON
# Nada en CoinGecko
# Nada en CoinMarketCap
# arkenfinance - ARKEN
# Nada en CoinGecko
# Hay patch: contract_address - A
# arkenstone - ARKN
# Nada en CoinGecko
# Hay patch: contract_address - A
# aaromi - ARM
# Nada en CoinGecko
# Hay patch: contract_address - A
# ammeris platform - ARMS
# Nada en CoinGecko
# Nada en CoinMarketCap
# antavira - ARMT
# Nada en CoinGecko
# Nada en CoinMarketCap
# aeron - ARN
# Nada en CoinGecko
# arena - ARNA
# Nada en CoinGecko
# Nada en CoinMarketCap
# arna panacea - ARNA
# Nada en CoinGecko
# Nada en CoinMarketCap
# arno - ARNO
# Nada en CoinGecko
# Hay patch: contract_address - A
# bitarq - ARQ
# Nada en CoinGecko
# Hay patch: contract_address - A
# arround - ARR
# Nada en CoinGecko
# Hay patch: contract_address - A
# blockarray - ARRAY
# Nada en CoinGecko
# Hay patch: contract_address - A
# maecenas - ART
# Nada en CoinGecko
# Hay patch: contract_address - A
# maecenas - ART
# Hay patch: contract_address - A
# art value - ARTS
# Nada en CoinGecko
# Hay patch: contract_address - A
# arttnetwork - ARTT
# Nada en CoinGecko
# Hay patch: contract_address - A
# artyfact - ARTY
# Nada en CoinGecko
# Hay patch: contract_address - A
# artex global - ARX
# Nada en CoinGecko
# Hay patch: contract_address - A
# assistive reality - ARX
# Nada en CoinGecko
# Hay patch: contract_address - A
# blockarray - ARY
# Nada en CoinGecko
# Hay patch: contract_address - A
# agro stock exchange - ASET
# Nada en CoinGecko
# Hay patch: contract_address - A
# asgard eco fund - ASG
# Nada en CoinGecko
# Nada en CoinMarketCap
# allspark - ASK
# Nada en CoinGecko
# Nada en CoinMarketCap
# the aslan project - ASL
# Nada en CoinGecko
# Nada en CoinMarketCap
# aceso network - ASO
# Nada en CoinGecko
# Nada en CoinMarketCap
# asure network - ASR
# Hay patch: contract_address - A
# afterschool - AST
# Hay patch: contract_address - A
# afterschool - AST
# Hay patch: contract_address - A
# asseta - AST
# Hay patch: contract_address - A
# asseta - AST
# Hay patch: contract_address - A
# all-stocks network - AST
# Hay patch: contract_address - A
# all-stocks network - AST
# Hay patch: contract_address - A
# assetstream - AST
# Nada en CoinGecko
# Hay patch: contract_address - A
# assetstream - AST
# Hay patch: contract_address - A
# astl token - ASTL
# Nada en CoinGecko
# astorgame - ASTOR
# Nada en CoinGecko
# Nada en CoinMarketCap
# arbitao - ATAO
# Nada en CoinGecko
# Nada en CoinMarketCap
# atbcoin - ATB
# Nada en CoinGecko
# Hay patch: contract_address - A
# agrotechfarm token - ATF
# Nada en CoinGecko
# Hay patch: contract_address - A
# atfs project - ATFS
# Nada en CoinGecko
# Nada en CoinMarketCap
# ethereum anonymizer - ATH
# Nada en CoinGecko
# Hay patch: contract_address - A
# aethercoin - ATH
# Nada en CoinGecko
# Hay patch: contract_address - A
# [400/5430] guardado cache...
# aigatha - ATH
# Nada en CoinGecko
# Hay patch: contract_address - A
# atherium - ATH
# Nada en CoinGecko
# Hay patch: contract_address - A
# iac autounit - ATK
# Nada en CoinGecko
# Hay patch: contract_address - A
# atlantico network - ATL
# Nada en CoinGecko
# Hay patch: contract_address - A
# staratlas - ATLAS
# Nada en CoinGecko
# Hay patch: contract_address - A
# autonomy - ATNMY
# Nada en CoinGecko
# Nada en CoinMarketCap
# atomicnetwork - ATOM
# Nada en CoinGecko
# Hay patch: contract_address - A
# atomic network - ATOMIC
# Nada en CoinGecko
# Hay patch: contract_address - A
# atlasplatform - ATPL
# Nada en CoinGecko
# Nada en CoinMarketCap
# aeternus foundation - ATRNO
# Nada en CoinGecko
# Nada en CoinMarketCap
# atronocom dmcc - ATROM
# Nada en CoinGecko
# Nada en CoinMarketCap
# artis - ATS
# Nada en CoinGecko
# Nada en CoinMarketCap
# airtoto - ATT
# Nada en CoinGecko
# Nada en CoinMarketCap
# attention network - ATTN
# Nada en CoinGecko
# Hay patch: contract_address - A
# alttradex - ATXT
# Nada en CoinGecko
# Nada en CoinMarketCap
# auctus project - AUC
# Nada en CoinGecko
# Hay patch: contract_address - A
# auctus - AUC
# Nada en CoinGecko
# Hay patch: contract_address - A
# audax project - AUDAX
# Nada en CoinGecko
# Nada en CoinMarketCap
# aussie digital - AUDCOIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# audrey blockchain harvester - AUDR
# Nada en CoinGecko
# Nada en CoinMarketCap
# aurora ecosystem - AUK
# Nada en CoinGecko
# Nada en CoinMarketCap
# alteum - AUM
# Nada en CoinGecko
# Hay patch: contract_address - A
# authoreon - AUN
# Nada en CoinGecko
# Hay patch: contract_address - A
# aunite - AUNIT
# Nada en CoinGecko
# Hay patch: contract_address - A
# auoranex - AUO
# Nada en CoinGecko
# Nada en CoinMarketCap
# authpaper delivery - AUPC
# Nada en CoinGecko
# Nada en CoinMarketCap
# aurumcoin - AUR
# Nada en CoinGecko
# Hay patch: contract_address - A
# aurora - AURA
# Nada en CoinGecko
# Hay patch: contract_address - A
# aura market - AURA
# Nada en CoinGecko
# Hay patch: contract_address - A
# auricoin - AURICOIN
# Nada en CoinGecko
# aurora - AURORA
# Nada en CoinGecko
# Hay patch: contract_address - A
# aurum.services - AURUM
# Nada en CoinGecko
# Hay patch: contract_address - A
# aurory - AURY
# Nada en CoinGecko
# Hay patch: contract_address - A
# autoblock - AUTOCOIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# aqvi - AV
# Nada en CoinGecko
# Nada en CoinMarketCap
# av4 - AV4
# Nada en CoinGecko
# Nada en CoinMarketCap
# avago - AVA
# Nada en CoinGecko
# avago - AVA
# avai football club - AVAI
# Hay patch: contract_address - A
# avantgarde ratings - AVG
# Hay patch: contract_address - A
# avinoc - AVINOC
# Nada en CoinGecko
# Hay patch: contract_address - A
# availcom - AVL
# Nada en CoinGecko
# Hay patch: contract_address - A
# avilom - AVM
# Nada en CoinGecko
# Hay patch: contract_address - A
# avilom ai - AVM
# Nada en CoinGecko
# Hay patch: contract_address - A
# aventus - AVT
# Nada en CoinGecko
# Hay patch: contract_address - A
# adverx - AVX
# Nada en CoinGecko
# Hay patch: contract_address - A
# awaxx - AWAX
# Nada en CoinGecko
# Nada en CoinMarketCap
# whatsonpic - AWT
# Nada en CoinGecko
# Hay patch: contract_address - A
# alpha-x - AX
# Nada en CoinGecko
# Hay patch: contract_address - A
# ax1 - AX1
# Nada en CoinGecko
# Nada en CoinMarketCap
# [450/5430] guardado cache...
# autoxchange - AXC
# Nada en CoinGecko
# Hay patch: contract_address - A
# axel - AXEL
# Nada en CoinGecko
# Hay patch: contract_address - A
# axionv - AXION
# Nada en CoinGecko
# laneaxis - AXIS
# Nada en CoinGecko
# Hay patch: contract_address - A
# axial entertainment blockchain - AXL
# Nada en CoinGecko
# Hay patch: contract_address - A
# axl inu - AXL
# Nada en CoinGecko
# Hay patch: contract_address - A
# axnet - AXN
# Nada en CoinGecko
# Hay patch: contract_address - A
# axos - AXO
# Nada en CoinGecko
# Hay patch: contract_address - A
# axpire - AXPR
# Nada en CoinGecko
# Hay patch: contract_address - A
# axpire - AXPR
# Hay patch: contract_address - A
# axens - AXS
# Nada en CoinGecko
# Hay patch: contract_address - A
# az fundchain - AZ
# Nada en CoinGecko
# Hay patch: contract_address - A
# kaliza - AZA
# Nada en CoinGecko
# Hay patch: contract_address - A
# azbi - AZBI
# Nada en CoinGecko
# ai-zeus blockchain - AZS
# Nada en CoinGecko
# Nada en CoinMarketCap
# azfundchain - AZT
# Nada en CoinGecko
# azultec - AZU
# Nada en CoinMarketCap
# b21 - B21
# Nada en CoinGecko
# Hay patch: contract_address - B
# b2bx - B2BX
# Nada en CoinGecko
# Nada en CoinMarketCap
# b2and - B2C
# Nada en CoinGecko
# b2and - B2C
# bitcoiin 2gen - B2G
# Nada en CoinGecko
# Hay patch: contract_address - B
# baanxcom - BAANX
# Nada en CoinGecko
# Nada en CoinMarketCap
# bablos - BABLOS
# Nada en CoinGecko
# Nada en CoinMarketCap
# driiven - BAC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bace exchange - BACE
# Nada en CoinGecko
# backcoin - BACK
# Nada en CoinGecko
# Hay patch: contract_address - B
# baiju - BAI
# Nada en CoinGecko
# Hay patch: contract_address - B
# bailsman - BAILS
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockaip - BAIP
# Nada en CoinGecko
# Nada en CoinMarketCap
# tokenbacon - BAK
# Nada en CoinGecko
# Hay patch: contract_address - B
# browsers lab - BAL
# Nada en CoinGecko
# Hay patch: contract_address - B
# ballcoin - BALL
# Nada en CoinGecko
# Hay patch: contract_address - B
# ballot coin - BALLOT
# Nada en CoinGecko
# Nada en CoinMarketCap
# fortbanana - BANAN
# Nada en CoinGecko
# Hay patch: contract_address - B
# bancabanc - BANCA
# Nada en CoinGecko
# Nada en CoinMarketCap
# bandprotocol - BAND
# Nada en CoinGecko
# bounty angels - BANG
# Nada en CoinGecko
# Nada en CoinMarketCap
# global crypto bank - BANK
# Nada en CoinGecko
# Nada en CoinMarketCap
# titanium blockchain infrastructure services - BAR
# Nada en CoinGecko
# Nada en CoinMarketCap
# bartcoin - BARC
# Nada en CoinGecko
# bartertrade - BART
# Hay patch: contract_address - B
# baasid - BAS
# Hay patch: contract_address - B
# chronobase - BASE
# Hay patch: contract_address - B
# basicattentiontoken - BAT
# Nada en CoinGecko
# Hay patch: contract_address - B
# mark snow - BATC
# Nada en CoinGecko
# Nada en CoinMarketCap
# batmine - BATM
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockav - BAV
# Nada en CoinGecko
# babb - BAX
# Nada en CoinGecko
# Hay patch: contract_address - B
# tradovebbc - BBC
# Nada en CoinGecko
# Hay patch: contract_address - B
# [500/5430] guardado cache...
# bytebet - BBET
# Nada en CoinGecko
# Nada en CoinMarketCap
# belugapay - BBI
# Nada en CoinGecko
# Hay patch: contract_address - B
# brickblock - BBK
# Nada en CoinGecko
# Hay patch: contract_address - B
# bbiller - BBL
# Nada en CoinGecko
# Hay patch: contract_address - B
# bigbom eco - BBO
# Nada en CoinGecko
# Hay patch: contract_address - B
# blackboxfoundation - BBOS
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitboost - BBT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitboost - BBT
# Hay patch: contract_address - B
# blockchain based bike token - BBT
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockchain based bike token - BBT
# Hay patch: contract_address - B
# blockbitsio - BBX
# Nada en CoinGecko
# Nada en CoinMarketCap
# bluebelt coin - BBXC
# Nada en CoinGecko
# Nada en CoinMarketCap
# block-chain - BC
# Nada en CoinGecko
# Hay patch: contract_address - B
# block-chain - BC
# Hay patch: contract_address - B
# block-chain - BC
# Hay patch: contract_address - B
# blockchaincapital - BCAP
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockcart - BCART
# Nada en CoinGecko
# bankcoin - BCASH
# Nada en CoinGecko
# bcb atm - BCB
# Nada en CoinGecko
# Nada en CoinMarketCap
# beercoin - BCBC
# bitchord - BCD
# Hay patch: contract_address - B
# bcedex exchange - BCDX
# Nada en CoinGecko
# Nada en CoinMarketCap
# bee cashback home - BCH
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitchemical defi - BCHEC
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoinichip - BCI
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockchain.io - BCIO
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockonomics - BCK
# Nada en CoinGecko
# Hay patch: contract_address - B
# bananacoin - BCO
# Nada en CoinGecko
# Hay patch: contract_address - B
# bcshop.io - BCS
# Nada en CoinGecko
# Hay patch: contract_address - B
# bcoin.sg - BCT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bcoin.sg - BCT
# Hay patch: contract_address - B
# bitcort - BCT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcort - BCT
# Hay patch: contract_address - B
# bitcoinxash - BCX
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockx - BCX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bridge - BD
# Nada en CoinGecko
# Hay patch: contract_address - B
# bdaq - BDAQ
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitdouble - BDBL
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitdegree - BDG
# Nada en CoinGecko
# Hay patch: contract_address - B
# govearn - BDLR
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitdepositary - BDT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bdeals token - BDT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bdtcoin - BDTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# beldex - BDX
# Nada en CoinGecko
# Hay patch: contract_address - B
# beam wallet - BEAM
# Nada en CoinGecko
# Nada en CoinMarketCap
# beat - BEAT
# Nada en CoinGecko
# bedcoin - BEDCOIN
# Nada en CoinGecko
# winminer - BEE
# Nada en CoinGecko
# beefcoin - BEEF
# Hay patch: contract_address - B
# breweryconsortium - BEER
# Hay patch: contract_address - B
# [550/5430] guardado cache...
# belotto - BEL
# Nada en CoinGecko
# Hay patch: contract_address - B
# belotto - BEL
# Hay patch: contract_address - B
# beldex - BELDEX
# Nada en CoinGecko
# bitengen coin - BENG
# Nada en CoinGecko
# Hay patch: contract_address - B
# dhabicoin - BEP-20
# Nada en CoinGecko
# Nada en CoinMarketCap
# bep40 coin - BEP40
# Nada en CoinGecko
# Nada en CoinMarketCap
# bep40.com - BEP40
# Nada en CoinGecko
# Nada en CoinMarketCap
# bergmannos - BERG
# Nada en CoinGecko
# Nada en CoinMarketCap
# mineberg - BERG
# Nada en CoinGecko
# Nada en CoinMarketCap
# rentberry - BERRY
# Nada en CoinGecko
# Hay patch: contract_address - B
# daocasino - BET
# Nada en CoinGecko
# Hay patch: contract_address - B
# betcoin - BETC
# Nada en CoinGecko
# Hay patch: contract_address - B
# betevent - BETEC
# Nada en CoinGecko
# Nada en CoinMarketCap
# bet50 - BETFTY
# Nada en CoinGecko
# Nada en CoinMarketCap
# bethereum - BETHER
# Nada en CoinGecko
# Hay patch: contract_address - B
# betinreal - BETINREAL
# Nada en CoinGecko
# Nada en CoinMarketCap
# betmaster - BETM
# Nada en CoinGecko
# Nada en CoinMarketCap
# betopen - BETOP
# Nada en CoinGecko
# Nada en CoinMarketCap
# betterbetting.org - BETR
# Nada en CoinGecko
# betley - BETS
# Nada en CoinGecko
# Nada en CoinMarketCap
# bettium - BETT
# Nada en CoinGecko
# Nada en CoinMarketCap
# betix - BETX
# Nada en CoinGecko
# Nada en CoinMarketCap
# binex trade - BEX
# Nada en CoinGecko
# Nada en CoinMarketCap
# burstex - BEX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitferry - BF
# Hay patch: contract_address - B
# biafracoin - BFC
# Hay patch: contract_address - B
# biofactorycoin - BFC
# Hay patch: contract_address - B
# btric - BFD
# Nada en CoinGecko
# Nada en CoinMarketCap
# befund - BFDT
# Nada en CoinGecko
# Nada en CoinMarketCap
# bfex - BFEX
# Nada en CoinGecko
# blocform - BFG
# Nada en CoinGecko
# Hay patch: contract_address - B
# benefit mine - BFM
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockfollow - BFN
# Nada en CoinGecko
# Nada en CoinMarketCap
# bond film platform - BFP
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockfood - BFT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bonum - BFT
# Nada en CoinGecko
# Hay patch: contract_address - B
# idap.io - BFX
# Nada en CoinGecko
# Hay patch: contract_address - B
# mobile money remittance system - BFY
# Nada en CoinGecko
# Nada en CoinMarketCap
# bluegold - BG
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitgold - BGD
# Nada en CoinGecko
# billandgo - BGO
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitgame - BGX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bh network - BHAT
# Nada en CoinGecko
# Hay patch: contract_address - B
# blue hill foundation - BHF
# Nada en CoinGecko
# Nada en CoinMarketCap
# bahiti coin - BHI
# Nada en CoinGecko
# Nada en CoinMarketCap
# bether - BHR
# Nada en CoinGecko
# bithub - BHT
# Nada en CoinGecko
# bitconia - BIA
# Nada en CoinGecko
# bico - BICO
# Hay patch: contract_address - B
# blockbid - BID
# Hay patch: contract_address - B
# [600/5430] guardado cache...
# bid auction - BIDA
# Nada en CoinGecko
# Nada en CoinMarketCap
# bidium - BIDIUM
# Nada en CoinGecko
# Nada en CoinMarketCap
# scruge - BIDL
# Nada en CoinGecko
# Nada en CoinMarketCap
# bidium - BIDM
# Nada en CoinGecko
# Nada en CoinMarketCap
# bidshop - BIDS
# Nada en CoinGecko
# Hay patch: contract_address - B
# big - BIG
# Nada en CoinGecko
# Hay patch: contract_address - B
# bill crypto - BILLS
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitimage - BIM
# Nada en CoinGecko
# Hay patch: contract_address - B
# binax - BIN
# Nada en CoinGecko
# Hay patch: contract_address - B
# binary - BINARY
# Nada en CoinGecko
# Nada en CoinMarketCap
# bionic - BINC
# Nada en CoinGecko
# bitcoinbing - BING
# Nada en CoinGecko
# Nada en CoinMarketCap
# binocoin - BINO
# Nada en CoinGecko
# Hay patch: contract_address - B
# biopaycoin - BIO
# Nada en CoinGecko
# Hay patch: contract_address - B
# biido - BION
# Nada en CoinGecko
# Nada en CoinMarketCap
# biospiel - BIOSPIEL
# Nada en CoinGecko
# Nada en CoinMarketCap
# minter - BIP
# Nada en CoinGecko
# Hay patch: contract_address - B
# betinreal - BIR
# Nada en CoinGecko
# Nada en CoinMarketCap
# birdchain - BIRD
# Nada en CoinGecko
# bitrewards - BIT
# Nada en CoinGecko
# bitrewards - BIT
# bit money - BIT
# Nada en CoinGecko
# bit money - BIT
# bitsync exchange - BITC
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcar - BITCAR
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcci cash - BITCCA
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitecoinnetwork - BITECOIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitfex - BITFEX
# Nada en CoinGecko
# bitcoin & company network - BITN
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitpaction - BITPACTION
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoinus - BITS
# Nada en CoinGecko
# Hay patch: contract_address - B
# tradeone - BITT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitto exchange - BITTO
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitscreener - BITX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bit world exchange - BIW
# Nada en CoinGecko
# Nada en CoinMarketCap
# biznek - big gopnik biznis - BIZN
# Nada en CoinGecko
# Nada en CoinMarketCap
# block broker - BKBK
# Nada en CoinGecko
# Nada en CoinMarketCap
# facts - BKC
# Nada en CoinGecko
# Hay patch: contract_address - B
# baikalika - BKL
# Nada en CoinGecko
# Nada en CoinMarketCap
# brickken - BKN
# Nada en CoinGecko
# Hay patch: contract_address - B
# battleknight - BKN
# Nada en CoinGecko
# Hay patch: contract_address - B
# blankox - BKO
# Nada en CoinGecko
# Nada en CoinMarketCap
# baby king - BKT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bankex - BKX
# Nada en CoinGecko
# Hay patch: contract_address - B
# blablagame.io - BLA
# Nada en CoinGecko
# Hay patch: contract_address - B
# blackfolio - BLACK
# Nada en CoinGecko
# Nada en CoinMarketCap
# bilibit - BLB
# Nada en CoinGecko
# Nada en CoinMarketCap
# blackcat - BLC
# Nada en CoinGecko
# billiardo game - BLD
# Hay patch: contract_address - B
# boldpure - BLDP
# Nada en CoinGecko
# Nada en CoinMarketCap
# [650/5430] guardado cache...
# linkbyblockmason - BLINK
# Nada en CoinGecko
# Hay patch: contract_address - B
# blinked - BLKD
# Nada en CoinGecko
# Nada en CoinMarketCap
# billion - BLLN
# Nada en CoinGecko
# blok - BLO
# Nada en CoinGecko
# Nada en CoinMarketCap
# block sailor - BLOCK
# Nada en CoinGecko
# Hay patch: contract_address - B
# blokcoin - BLOKS
# Nada en CoinGecko
# blowfish tequila - BLOWFISH
# Nada en CoinGecko
# Nada en CoinMarketCap
# blastup - BLP
# Nada en CoinGecko
# Hay patch: contract_address - B
# bills - BLS
# Nada en CoinGecko
# Hay patch: contract_address - B
# bills - BLS
# Hay patch: contract_address - B
# blue sky lithium coin - BLSX
# Nada en CoinGecko
# Nada en CoinMarketCap
# blitcoin - BLT
# Nada en CoinGecko
# Hay patch: contract_address - B
# blitcoin - BLT
# Hay patch: contract_address - B
# blueone - BLU
# Nada en CoinGecko
# Hay patch: contract_address - B
# blupassico - BLU
# Nada en CoinGecko
# Hay patch: contract_address - B
# bluetherium - BLUT
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockvest - BLV
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitlearn - BLX
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockscart - BLXS
# Nada en CoinGecko
# bluzelle - BLZ
# Nada en CoinGecko
# bitcomo - BM
# Nada en CoinGecko
# burger machine - BM
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoinmax - BMAX
# Nada en CoinGecko
# bmbcoin - BMB
# Nada en CoinGecko
# Hay patch: contract_address - B
# bank of memories - BMC
# Hay patch: contract_address - B
# bank of memories - BMC
# Hay patch: contract_address - B
# bitmart - BMC
# Hay patch: contract_address - B
# bitmart - BMC
# Hay patch: contract_address - B
# bismillahcoin - BMC
# Hay patch: contract_address - B
# bismillahcoin - BMC
# Hay patch: contract_address - B
# bitmex - BMEX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitminer factory - BMF
# Nada en CoinGecko
# Hay patch: contract_address - B
# borneo - BMG
# Nada en CoinGecko
# Hay patch: contract_address - B
# benchmark - BMK
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitminutes - BMT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bmybit - BMYC
# Nada en CoinGecko
# bitonenetwork - BN
# Nada en CoinGecko
# Hay patch: contract_address - B
# shibaspace - BNB
# Nada en CoinGecko
# Hay patch: contract_address - B
# omegatoken - BNB
# Nada en CoinGecko
# Hay patch: contract_address - B
# trivnex - BNB
# Nada en CoinGecko
# Hay patch: contract_address - B
# catfusion - BNB
# Nada en CoinGecko
# Hay patch: contract_address - B
# bnb dog inu - BNBDOG
# Nada en CoinGecko
# Hay patch: contract_address - B
# bnbmoney network - BNBM
# Nada en CoinGecko
# Nada en CoinMarketCap
# beancoin - BNC
# Nada en CoinGecko
# Hay patch: contract_address - B
# betconix bnix token - BNIX
# Nada en CoinGecko
# Nada en CoinMarketCap
# bankera - BNK
# Nada en CoinGecko
# Hay patch: contract_address - B
# bonkers - BNKR
# Nada en CoinGecko
# Hay patch: contract_address - B
# bancryp coin - BNP
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockchain neural system - BNS
# Nada en CoinGecko
# Hay patch: contract_address - B
# basis neuro - BNST
# Nada en CoinGecko
# Nada en CoinMarketCap
# [700/5430] guardado cache...
# bancor - BNT
# Nada en CoinGecko
# bounty0x - BNTY
# Nada en CoinGecko
# bob's repair - BOB
# Nada en CoinGecko
# brimpace - BOC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bocc.io - BOCC
# Nada en CoinGecko
# Nada en CoinMarketCap
# boxofdata - BOD
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockium - BOK
# Nada en CoinGecko
# Hay patch: contract_address - B
# boliecoin - BOLIE
# Nada en CoinGecko
# bolt - BOLT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bolttcoin - BOLTT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bonpay - BON
# Nada en CoinGecko
# Hay patch: contract_address - B
# warboy - BONES
# Nada en CoinGecko
# Hay patch: contract_address - B
# bonkcash - BONKC
# Nada en CoinGecko
# bonkdtrump - BONKDTRUMP
# Nada en CoinGecko
# Nada en CoinMarketCap
# bonkfast - BONKF
# Nada en CoinGecko
# Nada en CoinMarketCap
# book.io - BOOK
# Nada en CoinGecko
# Hay patch: contract_address - B
# pirate booty coin - BOOTY
# Nada en CoinGecko
# Nada en CoinMarketCap
# börser - BOR
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcollar - BOR
# Nada en CoinGecko
# Hay patch: contract_address - B
# bostoken - BOS
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitbose - BOSE
# Nada en CoinGecko
# bitcoin lottery - BOT
# Nada en CoinGecko
# Hay patch: contract_address - B
# botxcoin - BOTX
# Nada en CoinGecko
# Hay patch: contract_address - B
# boulé - BOU
# Nada en CoinGecko
# Nada en CoinMarketCap
# bouncy - BOUNCY
# Nada en CoinGecko
# Nada en CoinMarketCap
# bountie - BOUNTIE
# Nada en CoinGecko
# Nada en CoinMarketCap
# boutspro - BOUTS
# Nada en CoinGecko
# blueocean vc - BOV
# Nada en CoinGecko
# Nada en CoinMarketCap
# contentbox - BOX
# Hay patch: contract_address - B
# bitozz - BOZZ
# Nada en CoinGecko
# Nada en CoinMarketCap
# backpacktravel - BP
# Nada en CoinGecko
# Hay patch: contract_address - B
# black pound coin - BPC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitparadise - BPD
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockchain property gate - BPGT
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockpool - BPL
# Nada en CoinGecko
# Hay patch: contract_address - B
# blackpearl.chain - BPLC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitpaction - BPS
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitproperty.online - BPS
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockport - BPT
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockpix - BPX
# Nada en CoinGecko
# Hay patch: contract_address - B
# better. quick. transparent - BQTX
# Nada en CoinGecko
# Hay patch: contract_address - B
# brandprotect - BRAND
# Nada en CoinGecko
# Hay patch: contract_address - B
# brics coin - BRC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bread - BRD
# Nada en CoinGecko
# Hay patch: contract_address - B
# eiracube - BRETT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bring - BRG
# Nada en CoinGecko
# Hay patch: contract_address - B
# brumh - BRH
# Nada en CoinGecko
# Nada en CoinMarketCap
# burning horse - BRHS
# Nada en CoinGecko
# Nada en CoinMarketCap
# bricbit - BRICBIT
# Nada en CoinGecko
# Nada en CoinMarketCap
# brickvision - BRICKS
# Nada en CoinGecko
# Nada en CoinMarketCap
# [750/5430] guardado cache...
# cryptobrick - BRIK
# Nada en CoinGecko
# brikbit - BRIK
# Nada en CoinGecko
# Nada en CoinMarketCap
# brikcoin - BRIK
# Nada en CoinGecko
# pinnaclebrilliance - BRIL
# Nada en CoinGecko
# Nada en CoinMarketCap
# bizzshare - BRIX
# Nada en CoinMarketCap
# brick - BRKC
# bioritmai - BRM
# Nada en CoinGecko
# Hay patch: contract_address - B
# brem - BRM
# Nada en CoinGecko
# Hay patch: contract_address - B
# brainerz - BRNZ
# Nada en CoinGecko
# Nada en CoinMarketCap
# brofistcoin - BRO
# Nada en CoinGecko
# Hay patch: contract_address - B
# themancaveproject - BROCOIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# bronix - BRONIX
# Nada en CoinGecko
# Nada en CoinMarketCap
# browniesswap - BROWN
# Nada en CoinGecko
# Hay patch: contract_address - B
# bravesoundtoken - BRST
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitnan - BRT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitribe token - BRT
# Nada en CoinGecko
# Hay patch: contract_address - B
# bertinity - BRTX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bravocoin - BRV
# Nada en CoinGecko
# Nada en CoinMarketCap
# breezecoin - BRZC
# Nada en CoinGecko
# brayzin - BRZN
# Nada en CoinGecko
# Nada en CoinMarketCap
# blackstallion - BS
# Nada en CoinGecko
# Hay patch: contract_address - B
# bsbcoin - BSB
# Nada en CoinGecko
# Hay patch: contract_address - B
# bsb fund - BSBF
# Nada en CoinGecko
# Nada en CoinMarketCap
# boonscoin - BSC
# Nada en CoinGecko
# Hay patch: contract_address - B
# boonscoin - BSC
# Hay patch: contract_address - B
# boonscoin - BSC
# Hay patch: contract_address - B
# mechamusk - BSC
# Nada en CoinGecko
# Hay patch: contract_address - B
# mechamusk - BSC
# Hay patch: contract_address - B
# mechamusk - BSC
# Hay patch: contract_address - B
# bull star finance - BSF
# Nada en CoinGecko
# Hay patch: contract_address - B
# blocksquare - BST
# Nada en CoinGecko
# Hay patch: contract_address - B
# blocksquare - BST
# Hay patch: contract_address - B
# blocksquare - BST
# Hay patch: contract_address - B
# boosto - BST
# Nada en CoinGecko
# Hay patch: contract_address - B
# boosto - BST
# Hay patch: contract_address - B
# boosto - BST
# Hay patch: contract_address - B
# bitsoftbay - BSTX
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitspace - BSX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bow - BT
# Nada en CoinGecko
# Hay patch: contract_address - B
# brain to brain token - BTBT
# Nada en CoinGecko
# Nada en CoinMarketCap
# milkyway coin - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bits diamond - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# abot coin - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# just pay coin - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcheke - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# ggrocket - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# murphy roofing pro - BTC
# Nada en CoinGecko
# Hay patch: contract_address - B
# btc-20 - BTC20
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoin2022 - BTC2022
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoin asia - BTCA
# Nada en CoinGecko
# [800/5430] guardado cache...
# bitconcent - BTCC
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitcoin crown - BTCC
# Nada en CoinGecko
# Nada en CoinMarketCap
# mineable bitcoin on ethereum mainnet - BTCE
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitconscious foundation - BTCF
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcoingo - BTCG
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitcoinoil - BTCO
# Nada en CoinGecko
# Nada en CoinMarketCap
# btcsearch - BTCSEARCH
# Nada en CoinGecko
# Nada en CoinMarketCap
# bitscoin - BTCX
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitdraw - BTDW
# Nada en CoinGecko
# Nada en CoinMarketCap
# bittech - BTECH
# Nada en CoinGecko
# Nada en CoinMarketCap
# blocktrade exchange token - BTEX
# Nada en CoinGecko
# Hay patch: contract_address - B
# blockchain traded fund - BTF
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitrust - BTF
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitheum - BTH
# Nada en CoinGecko
# Hay patch: contract_address - B
# bit.la - BTL
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitmond - BTM
# Nada en CoinGecko
# Hay patch: contract_address - B
# bitroom - BTM
# Nada en CoinGecko
# ...
# Nada en CoinGecko
# Hay patch: contract_address - X
# xcrypt - XCT
# Nada en CoinGecko
# Hay patch: contract_address - X
# capacity transfer radio - XCTR
# Nada en CoinGecko
# Nada en CoinMarketCap
# causevest - XCV
# Nada en CoinGecko
# Hay patch: contract_address - X
# thecryptowatch - XCW
# Nada en CoinGecko
# Nada en CoinMarketCap
# xdac - XDAC
# Nada en CoinGecko
# Nada en CoinMarketCap
# xdai - XDAI
# Nada en CoinGecko
# Hay patch: contract_address - x
# digitalbits - XDB
# Nada en CoinGecko
# Hay patch: contract_address - X
# xinfin - XDCE
# Nada en CoinGecko
# Nada en CoinMarketCap
# defundproject - XDF
# Nada en CoinGecko
# Nada en CoinMarketCap
# dataeum - XDT
# Nada en CoinGecko
# Nada en CoinMarketCap
# ebosia - XEBS
# Nada en CoinGecko
# Nada en CoinMarketCap
# xenia coin - XEN
# Nada en CoinGecko
# Nada en CoinMarketCap
# xenoverse - XENO
# Nada en CoinGecko
# Hay patch: contract_address - X
# xera - XERA
# xerium - XERM
# Nada en CoinGecko
# Hay patch: contract_address - X
# cryptex network - XET
# Nada en CoinGecko
# Hay patch: contract_address - X
# xfermoney - XFM
# Nada en CoinGecko
# Nada en CoinMarketCap
# fructus - XFRC
# Nada en CoinGecko
# Hay patch: contract_address - X
# xgames - XG
# Nada en CoinGecko
# Hay patch: contract_address - X
# xge token - XGE
# Nada en CoinGecko
# next generation - XGEN
# Nada en CoinGecko
# Nada en CoinMarketCap
# goloud - XGLD
# Nada en CoinGecko
# Nada en CoinMarketCap
# xaurum gamma - XGM
# Nada en CoinGecko
# Hay patch: contract_address - X
# golden currency - XGN
# Nada en CoinGecko
# Nada en CoinMarketCap
# gptoken - XGP
# Nada en CoinGecko
# Hay patch: contract_address - X
# hedge coin - XHC
# Nada en CoinGecko
# sphreair - XID
# Nada en CoinGecko
# Hay patch: contract_address - X
# x infinity - XIF
# Nada en CoinGecko
# Hay patch: contract_address - X
# impresso - XIM
# Nada en CoinGecko
# Hay patch: contract_address - X
# xirkle - XIR
# Nada en CoinGecko
# Nada en CoinMarketCap
# xiwatt - XIW
# Nada en CoinGecko
# Nada en CoinMarketCap
# kinekt terminals - XKN
# Nada en CoinGecko
# Nada en CoinMarketCap
# [5200/5430] guardado cache...
# konero - XKO
# Nada en CoinGecko
# Nada en CoinMarketCap
# shaaare - XKO
# Nada en CoinGecko
# Nada en CoinMarketCap
# stellargold - XLMG
# Nada en CoinGecko
# stellargoldcoin - XLMGOLD
# Nada en CoinGecko
# Nada en CoinMarketCap
# loopexieo - XLP
# Nada en CoinGecko
# Nada en CoinMarketCap
# xunilair - XLR
# Nada en CoinGecko
# Hay patch: contract_address - X
# lumenus - XLS
# Nada en CoinGecko
# Hay patch: contract_address - X
# xenialendingcoin - XLT
# Nada en CoinGecko
# Hay patch: contract_address - X
# mingo - XMC
# Nada en CoinGecko
# Hay patch: contract_address - X
# mydexpay xmd - XMD
# Nada en CoinGecko
# Hay patch: contract_address - X
# xmoneta - XMN
# Nada en CoinGecko
# Hay patch: contract_address - X
# moo token sale - XMOO
# Nada en CoinGecko
# Nada en CoinMarketCap
# xmp - XMP
# Nada en CoinGecko
# Nada en CoinMarketCap
# xmaterials - XMT
# Nada en CoinGecko
# Hay patch: contract_address - X
# industria - XND
# Nada en CoinGecko
# Nada en CoinMarketCap
# inkprotocol - XNK
# Nada en CoinGecko
# Hay patch: contract_address - X
# sunx - XNS
# Nada en CoinGecko
# Hay patch: contract_address - X
# exenium - XNT
# Nada en CoinGecko
# Nada en CoinMarketCap
# exenium - XNT
# xcent - XNT
# Nada en CoinGecko
# Nada en CoinMarketCap
# xcent - XNT
# omnibazaar - XOM
# Nada en CoinGecko
# Nada en CoinMarketCap
# oracol - XOR
# Nada en CoinGecko
# Hay patch: contract_address - X
# bitxoxo - XOXO
# Nada en CoinGecko
# Hay patch: contract_address - X
# xpa - XPA
# Nada en CoinGecko
# Hay patch: contract_address - X
# bitnation - XPAT
# Nada en CoinGecko
# Hay patch: contract_address - X
# explorecoin - XPC
# Nada en CoinGecko
# Hay patch: contract_address - X
# exclusive platform - XPL
# Nada en CoinGecko
# Hay patch: contract_address - X
# pantheonx - XPN
# Nada en CoinGecko
# Hay patch: contract_address - X
# xpool - XPO
# Nada en CoinGecko
# Hay patch: contract_address - X
# cryptoxpress - XPT
# Nada en CoinGecko
# Nada en CoinMarketCap
# privelege coin - XPV
# Nada en CoinGecko
# Nada en CoinMarketCap
# privelege coin - XPV
# proximax - XPX
# Hay patch: contract_address - X
# proximax - XPX
# Hay patch: contract_address - X
# proximax - XPX
# Hay patch: contract_address - X
# properbuz - XPZ
# Nada en CoinGecko
# Nada en CoinMarketCap
# qredit (rebranded) - XQR
# Nada en CoinGecko
# Hay patch: contract_address - X
# xriba - XRA
# Nada en CoinGecko
# Hay patch: contract_address - X
# xtribe - XRBT
# Nada en CoinGecko
# x real estate development - XRED
# Nada en CoinGecko
# Nada en CoinMarketCap
# xrise - XRISE
# Nada en CoinGecko
# Hay patch: contract_address - X
# recordskeeper - XRK
# Nada en CoinGecko
# Nada en CoinMarketCap
# rialto - XRL
# Nada en CoinGecko
# Hay patch: contract_address - X
# refine medium - XRM
# Nada en CoinGecko
# Hay patch: contract_address - X
# arium20 - XRMT
# Nada en CoinGecko
# Nada en CoinMarketCap
# xrp20 - XRP20
# Nada en CoinGecko
# Hay patch: contract_address - X
# ripplecash - XRPC
# Nada en CoinGecko
# Hay patch: contract_address - X
# xchangerate - XRR
# Nada en CoinGecko
# Nada en CoinMarketCap
# xrt - XRT
# Nada en CoinGecko
# Hay patch: contract_address - X
# [5250/5430] guardado cache...
# xeron care - XRX
# Nada en CoinGecko
# Hay patch: contract_address - X
# xs2 exchange - XS2
# Nada en CoinGecko
# Nada en CoinMarketCap
# saturn black platform - XSAT
# Nada en CoinGecko
# Hay patch: contract_address - X
# stockbet - XSB
# Nada en CoinGecko
# Hay patch: contract_address - X
# securedonationtoken - XSD
# Nada en CoinGecko
# Hay patch: contract_address - X
# xsearch - XSE
# Nada en CoinGecko
# Nada en CoinMarketCap
# shopereum - XSHOP
# Nada en CoinGecko
# Nada en CoinMarketCap
# xsolus - XSO
# Nada en CoinGecko
# Nada en CoinMarketCap
# ethereum solo - XSO
# Nada en CoinGecko
# Nada en CoinMarketCap
# xsubyte - XSU
# Nada en CoinGecko
# Nada en CoinMarketCap
# zbx - XT
# Hay patch: contract_address - X
# extoke fee free dex! - XTO
# Hay patch: contract_address - X
# takeprofit - XTP
# Nada en CoinGecko
# Hay patch: contract_address - X
# tetrix token - XTR
# Nada en CoinGecko
# Hay patch: contract_address - X
# bitcoinhomework - extracredit - XTRA
# Nada en CoinGecko
# Hay patch: contract_address - X
# xtrd - XTRD
# Nada en CoinGecko
# Hay patch: contract_address - X
# centive - XTV
# Nada en CoinGecko
# Hay patch: contract_address - X
# xtock - XTX
# Nada en CoinGecko
# Hay patch: contract_address - X
# tezos - XTZ
# Nada en CoinGecko
# Hay patch: contract_address - X
# u.cash - XUC
# Nada en CoinGecko
# Hay patch: contract_address - X
# ultroneum - XUM
# Nada en CoinGecko
# Nada en CoinMarketCap
# upgrade - XUP
# Nada en CoinGecko
# Hay patch: contract_address - X
# valuecash - XVL
# Nada en CoinGecko
# Nada en CoinMarketCap
# vantagetoken - XVT
# Nada en CoinGecko
# Nada en CoinMarketCap
# xwin cryptobet - XWIN
# Nada en CoinGecko
# Hay patch: contract_address - X
# century exchange - XXI
# Nada en CoinGecko
# Nada en CoinMarketCap
# xx platform - XXP
# Nada en CoinGecko
# Hay patch: contract_address - X
# airporn - XXX
# Nada en CoinGecko
# Hay patch: contract_address - X
# yudi - XYD
# Nada en CoinGecko
# Nada en CoinMarketCap
# xyo network - XYO
# Nada en CoinGecko
# Hay patch: contract_address - X
# yanubuks - XYUS
# Nada en CoinGecko
# Nada en CoinMarketCap
# yachtco - YACHTCO
# Nada en CoinGecko
# Nada en CoinMarketCap
# yanu - YANU
# Nada en CoinGecko
# Nada en CoinMarketCap
# yapswap - YAPS
# Nada en CoinGecko
# your best coin - YBC
# Nada en CoinGecko
# Nada en CoinMarketCap
# yellowbetter - YBT
# Nada en CoinGecko
# Nada en CoinMarketCap
# ten billion coin - YBY
# Nada en CoinGecko
# Nada en CoinMarketCap
# digital finance - YDGF
# Nada en CoinGecko
# Nada en CoinMarketCap
# yuandeveloperscoin - YDS
# Nada en CoinGecko
# Nada en CoinMarketCap
# your data safe - YDST
# Nada en CoinGecko
# Nada en CoinMarketCap
# ydentity - YDY
# Nada en CoinGecko
# Nada en CoinMarketCap
# yesil token - YESIL
# Nada en CoinGecko
# Nada en CoinMarketCap
# yesports - YESP
# Nada en CoinGecko
# Hay patch: contract_address - Y
# yezcoin - YEZ
# Nada en CoinGecko
# yearn finance money - YFIM
# Nada en CoinGecko
# Hay patch: contract_address - Y
# yearn finance red - YFIR
# Nada en CoinGecko
# yhfi.finance - YHFI
# Nada en CoinGecko
# yield coin - YLD
# Nada en CoinGecko
# Hay patch: contract_address - Y
# yacht master token - YMT
# Nada en CoinGecko
# Nada en CoinMarketCap
# yamzu - YMZ
# Nada en CoinGecko
# Nada en CoinMarketCap
# [5300/5430] guardado cache...
# yen coin - YNC
# Nada en CoinGecko
# yodse - YODSE
# Nada en CoinGecko
# Nada en CoinMarketCap
# yolotoken - YOLO
# Nada en CoinGecko
# Nada en CoinMarketCap
# yondocoin - YON
# Nada en CoinGecko
# Nada en CoinMarketCap
# yooba - YOO
# Nada en CoinGecko
# Nada en CoinMarketCap
# selfllery - YOU
# Nada en CoinGecko
# Nada en CoinMarketCap
# yooping - YPNG
# Nada en CoinGecko
# Nada en CoinMarketCap
# ypro.finance - YPRO
# Nada en CoinGecko
# Hay patch: contract_address - Y
# yptospace - YPTO
# Nada en CoinMarketCap
# youra - YRC
# Nada en CoinMarketCap
# yearn crypto - YRN
# Nada en CoinGecko
# Nada en CoinMarketCap
# fairninja - YSH
# Nada en CoinGecko
# Nada en CoinMarketCap
# ysign | a new way of communication! - YSN
# Nada en CoinGecko
# Nada en CoinMarketCap
# yutucoin - YTC
# Nada en CoinGecko
# Hay patch: contract_address - Y
# youtoken - YTN
# Nada en CoinGecko
# Hay patch: contract_address - Y
# yumerium - YUM
# Nada en CoinGecko
# Hay patch: contract_address - Y
# yizoot - YUT
# Nada en CoinGecko
# Nada en CoinMarketCap
# yye (yi yuan energy) - YYE
# Nada en CoinGecko
# Hay patch: contract_address - Y
# zabercoin - ZAB
# Nada en CoinGecko
# zacrotribe - ZACRO
# Nada en CoinGecko
# Nada en CoinMarketCap
# zamanat - ZAMANAT
# Nada en CoinGecko
# Nada en CoinMarketCap
# zap - ZAP
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zapit - ZAPIT
# Nada en CoinGecko
# Nada en CoinMarketCap
# zayka token - ZAY
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zerobank - ZB
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zap clash: meme gamefi battle - ZC
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zecash - ZCH
# Nada en CoinGecko
# zerochain network - ZCHAIN
# Nada en CoinGecko
# Nada en CoinMarketCap
# 0chain - ZCHN
# Nada en CoinGecko
# zclassic gold - ZCLG
# Nada en CoinGecko
# Nada en CoinMarketCap
# zichain - ZCN
# Nada en CoinGecko
# zealeum - ZEAL
# zebrocoin - ZEBRO
# Nada en CoinMarketCap
# tradeplayz - ZED
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zeew - ZEEW
# Nada en CoinGecko
# Nada en CoinMarketCap
# zen the panda - ZEN
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zengold - ZENGOLD
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zeon network - ZEON
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zeosx - ZEOS
# Nada en CoinGecko
# Nada en CoinMarketCap
# zeroedge - ZERO
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zeroedgebet - ZEROCOIN/
# Nada en CoinGecko
# Nada en CoinMarketCap
# zeus - ZET
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zethereum - ZETH
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zetochain - ZETO
# Nada en CoinGecko
# zuenchain - ZEUNCH
# Nada en CoinGecko
# Nada en CoinMarketCap
# zeew - ZEWT
# Nada en CoinGecko
# Nada en CoinMarketCap
# zuflo - ZFL
# Nada en CoinGecko
# Hay patch: contract_address - Z
# ecex.exchange - ZIG
# Nada en CoinGecko
# Hay patch: contract_address - Z
# ziktalk - ZIK
# Nada en CoinGecko
# Hay patch: contract_address - Z
# chainzilla - ZILLA
# Nada en CoinGecko
# Hay patch: contract_address - Z
# [5350/5430] guardado cache...
# zin finance - ZIN
# Nada en CoinGecko
# coinzix - ZIX
# Nada en CoinGecko
# Nada en CoinMarketCap
# zktube - ZKT
# Nada en CoinGecko
# Nada en CoinMarketCap
# zilla - ZLA
# Nada en CoinGecko
# zenome - ZNA
# Nada en CoinGecko
# Nada en CoinMarketCap
# znaq - ZNAQ
# Nada en CoinGecko
# Nada en CoinMarketCap
# znc token - ZNC
# Nada en CoinGecko
# zeon - ZNC
# zonex - ZNX
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zonex - ZNX
# Hay patch: contract_address - Z
# zantepay - ZNX
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zantepay - ZNX
# Hay patch: contract_address - Z
# zodiaq - ZOD
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zelaapay - ZPAY
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zapcash - ZPC
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zper - ZPR
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zeepin chain - ZPT
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zoptax - ZPT
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zpunk token - ZPT
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zrcoin - ZRC
# Nada en CoinGecko
# Hay patch: contract_address - Z
# 0x - ZRX
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zortrax token - ZRXT
# Nada en CoinGecko
# Nada en CoinMarketCap
# zerostate - ZSC
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zeux - ZUC
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zue - ZUE
# Nada en CoinGecko
# Nada en CoinMarketCap
# zupply - ZUP
# Nada en CoinGecko
# Nada en CoinMarketCap
# movieschain - ZVR
# Nada en CoinGecko
# Nada en CoinMarketCap
# 0xcert - ZXC
# Nada en CoinGecko
# Hay patch: contract_address - Z
# zooomex - ZXE
# Nada en CoinGecko
# Nada en CoinMarketCap
# zynecoin - ZYN
# Nada en CoinGecko
# zozocoin - ZZC
# Nada en CoinGecko
# gosleep - ZZZ
# Nada en CoinGecko
# Nada en CoinMarketCap
# elitecoin - ЕTM
# Nada en CoinGecko
# crypto cams - СС
# Nada en CoinGecko
# Nada en CoinMarketCap
# etheal - Ḫ
# Nada en CoinGecko
# Nada en CoinMarketCap
# kapu coin - Ʞ
# Nada en CoinGecko
# Nada en CoinMarketCap
# asseta - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# bladedao - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# blockstack - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# bluesale - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# cogitoprotocol - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# coniun - nan
# Nada en CoinGecko
# cowswap - nan
# Nada en CoinGecko
# dangelfund - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# deeptoken - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# egopaysenger - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# ethernalheroes - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# fluzcoin - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# g4al - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# gearboxprotocol - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# [5400/5430] guardado cache...
# globitex - nan
# Nada en CoinGecko
# gloryfinance - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# goldfinchfinance - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# goracle - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# havven - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# hydradx - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# ikonic - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# kryptai - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# livetree - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# mantanetworkcrowdloan - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# oilernetwork - nan
# Nada en CoinGecko
# p2pep - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# parmafantoken - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# polygame - nan
# Nada en CoinGecko
# projectgalaxy - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# radicle - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# radixdlt - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# rewater - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# royalcapital - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# sp8de - nan
# Nada en CoinGecko
# staderlabs - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# starlyio - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# successlife - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# titanautonomous - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# ttcprotocol - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# umee - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# vanm - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# vitavisor - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# voxiestactics - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# youropenmetaverse - nan
# Nada en CoinGecko
# Nada en CoinMarketCap
# ✅ Guardado enriquecido: ../final/ico_dataset_final_v2_clean_enriquecido.csv
# Filas procesadas: 5430 | Filas con cambios: 2960 | Tiempo: 12512.4s
#
# Cobertura (no-nulos, %):
# kyc                      100.00%
# team_size                100.00%
# roadmap_available        100.00%
# category                  99.47%
# tokens_for_sale           88.66%
# token_type                64.05%
# token_symbol               0.00%
# token_name                 0.00%
# homepage                   0.00%
# whitepaper_url             0.00%
# github_url                 0.00%
# twitter_url                0.00%
# telegram_url               0.00%
# reddit_url                 0.00%
# token_price_usd            0.00%
# soft_cap_usd               0.00%
# hard_cap_usd               0.00%
# accepted_currencies        0.00%
# whitelist                  0.00%
# jurisdiction               0.00%
# has_github                 0.00%
# whitepaper_available       0.00%
# rating                     0.00%

# %%
# %%
aud = pd.read_csv(OUT_PATH)
audit_cols = ["symbol_std","token_symbol","token_name","homepage","whitepaper_url","github_url",
              "token_type","token_price_usd","soft_cap_usd","hard_cap_usd","kyc","whitelist","jurisdiction"]
coverage = aud[audit_cols].isna().mean().map(lambda x: round(100*(1-x),2)).sort_values(ascending=False)
print("Cobertura % no-nulos (desc):\n", coverage)

# Tokens aún sin símbolo resuelto
left = aud[(aud["symbol_std"].isna() | (aud["symbol_std"].astype(str).str.strip()=="")) &
           (aud["token_symbol"].isna() | (aud["token_symbol"].astype(str).str.strip()==""))]
print(f"\nPendientes de símbolo: {len(left)}")
left[["name_std"]].head(20)
# Out:
# Cobertura % no-nulos (desc):
#  kyc                100.00
# symbol_std          99.19
# token_type          64.05
# token_symbol         0.00
# token_name           0.00
# homepage             0.00
# whitepaper_url       0.00
# github_url           0.00
# token_price_usd      0.00
# soft_cap_usd         0.00
# hard_cap_usd         0.00
# whitelist            0.00
# jurisdiction         0.00
# dtype: float64
#
# Pendientes de símbolo: 44
#               name_std
# 5386            asseta
# 5387          bladedao
# 5388        blockstack
# 5389          bluesale
# 5390    cogitoprotocol
# 5391            coniun
# 5392           cowswap
# 5393        dangelfund
# 5394         deeptoken
# 5395      egopaysenger
# 5396    ethernalheroes
# 5397          fluzcoin
# 5398              g4al
# 5399   gearboxprotocol
# 5400          globitex
# 5401      gloryfinance
# 5402  goldfinchfinance
# 5403           goracle
# 5404            havven
# 5405           hydradx

# %%
bnb_cmc = pd.DataFrame({'status': {'timestamp': '2025-10-18T16:51:43.785Z', 'error_code': 0, 'error_message': None, 'elapsed': 22, 'credit_count': 1, 'notice': None}, 'data': {'BNB': [{'id': 1839, 'name': 'BNB', 'symbol': 'BNB', 'category': 'coin', 'description': 'BNB (BNB) is a cryptocurrency . BNB has a current supply of 139,180,845.25. The last known price of BNB is 1,083.71292096 USD and is up 0.65 over the last 24 hours. It is currently trading on 2825 active market(s) with $4,063,453,973.33 traded over the last 24 hours. More information can be found at https://bnbchain.org/en.', 'slug': 'bnb', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/1839.png', 'subreddit': 'bnbchainofficial', 'notice': '', 'tags': ['marketplace', 'centralized-exchange', 'payments', 'smart-contracts', 'alameda-research-portfolio', 'multicoin-capital-portfolio', 'bnb-chain-ecosystem', 'layer-1', 'alleged-sec-securities', 'celsius-bankruptcy-estate', 'binance-ecosystem', 'binance-listing', 'made-in-china'], 'tag-names': ['Marketplace', 'Centralized Exchange (CEX) Token', 'Payments', 'Smart Contracts', 'Alameda Research Portfolio', 'Multicoin Capital Portfolio', 'BNB Chain Ecosystem', 'Layer 1', 'Alleged SEC Securities', 'Celsius Bankruptcy Estate', 'Binance Ecosystem', 'Binance Listing', 'Made in China'], 'tag-groups': ['INDUSTRY', 'CATEGORY', 'INDUSTRY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'PLATFORM', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY'], 'urls': {'website': ['https://bnbchain.org/en'], 'twitter': ['https://twitter.com/bnbchain'], 'message_board': [], 'chat': ['https://t.me/BNBchaincommunity', 'https://t.me/bnbchain'], 'facebook': [], 'explorer': ['https://explorer.bnbchain.org/', 'https://app.nansen.ai/token-god-mode?chain=ethereum&tab=transactions&tokenAddress=0xb8c77482e45f1f44de1745f52c74426c631bdd52', 'https://bsctrace.com/', 'https://bscscan.com/token/0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c', 'https://www.okx.com/web3/explorer/bsc'], 'reddit': ['https://reddit.com/r/bnbchainofficial'], 'technical_doc': [], 'source_code': ['https://github.com/bnb-chain'], 'announcement': []}, 'platform': None, 'date_added': '2017-07-25T00:00:00.000Z', 'twitter_username': 'bnbchain', 'is_hidden': 0, 'date_launched': None, 'contract_address': [{'contract_address': '0xb8c77482e45f1f44de1745f52c74426c631bdd52', 'platform': {'name': 'Ethereum', 'coin': {'id': '1027', 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum'}}}, {'contract_address': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee', 'platform': {'name': 'BNB Smart Chain (BEP20)', 'coin': {'id': '1839', 'name': 'BNB', 'symbol': 'BNB', 'slug': 'bnb'}}}], 'self_reported_circulating_supply': None, 'self_reported_tags': None, 'self_reported_market_cap': None, 'infinite_supply': False}, {'id': 38157, 'name': 'BNB AI', 'symbol': 'BNB', 'category': 'token', 'description': 'BNB AI (BNB) is a cryptocurrency launched in 2025and operates on the BNB Smart Chain (BEP20) platform. BNB AI has a current supply of 139,000,000 with 0 in circulation. The last known price of BNB AI is 0.00013723 USD and is up 1.95 over the last 24 hours. It is currently trading on 1 active market(s) with $0.00 traded over the last 24 hours. More information can be found at https://bnbaitoken.xyz.', 'slug': 'bnb-ai', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/38157.png', 'subreddit': '', 'notice': 'Please note that this asset is not affiliated with [BNB Chain](https://www.bnbchain.org/en) in any way. Please exercise caution and [DYOR](https://support.coinmarketcap.com/hc/en-us/articles/360043659351-Listings-Criteria).', 'tags': ['memes', 'bnb-chain-ecosystem'], 'tag-names': ['Memes', 'BNB Chain Ecosystem'], 'tag-groups': ['INDUSTRY', 'PLATFORM'], 'urls': {'website': ['https://bnbaitoken.xyz'], 'twitter': ['https://twitter.com/BNBai_off'], 'message_board': [], 'chat': ['https://t.me/bnbaitoken'], 'facebook': [], 'explorer': ['https://bscscan.com/token/0x3376C5632f8047D009713884440c0020f2C66c85', 'https://app.nansen.ai/token-god-mode?chain=bnb&tab=transactions&tokenAddress=0x3376C5632f8047D009713884440c0020f2C66c85'], 'reddit': [], 'technical_doc': [], 'source_code': [], 'announcement': []}, 'platform': {'id': '1839', 'name': 'BNB', 'slug': 'bnb', 'symbol': 'BNB', 'token_address': '0x3376C5632f8047D009713884440c0020f2C66c85'}, 'date_added': '2025-08-21T07:23:17.000Z', 'twitter_username': 'BNBai_off', 'is_hidden': 0, 'date_launched': '2025-08-19T00:00:00.000Z', 'contract_address': [{'contract_address': '0x3376C5632f8047D009713884440c0020f2C66c85', 'platform': {'name': 'BNB Smart Chain (BEP20)', 'coin': {'id': '1839', 'name': 'BNB', 'symbol': 'BNB', 'slug': 'bnb'}}}], 'self_reported_circulating_supply': 139000000, 'self_reported_tags': None, 'self_reported_market_cap': 19075.277806922164, 'infinite_supply': False}, {'id': 38210, 'name': 'BNBTiger Inu', 'symbol': 'BNB', 'category': 'token', 'description': 'BNBTiger Inu (BNB) is a cryptocurrency launched in 2025and operates on the BNB Smart Chain (BEP20) platform. BNBTiger Inu has a current supply of 100,000,000 with 0 in circulation. The last known price of BNBTiger Inu is 0.00007918 USD and is down -0.88 over the last 24 hours. It is currently trading on 1 active market(s) with $0.00 traded over the last 24 hours. More information can be found at https://bnbtigerinu.xyz/.', 'slug': 'bnb-tiger-inu', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/38210.png', 'subreddit': '', 'notice': '', 'tags': ['memes', 'bnb-chain-ecosystem'], 'tag-names': ['Memes', 'BNB Chain Ecosystem'], 'tag-groups': ['INDUSTRY', 'PLATFORM'], 'urls': {'website': ['https://bnbtigerinu.xyz/'], 'twitter': ['https://twitter.com/BnbTigerInu_off'], 'message_board': [], 'chat': ['https://t.me/bnbtigerinu1'], 'facebook': [], 'explorer': ['https://bscscan.com/token/0xa05cCD2F8ac92afE092A7240E948aA3E17cEF843', 'https://app.nansen.ai/token-god-mode?chain=bnb&tab=transactions&tokenAddress=0xa05cCD2F8ac92afE092A7240E948aA3E17cEF843'], 'reddit': [], 'technical_doc': [], 'source_code': [], 'announcement': []}, 'platform': {'id': '1839', 'name': 'BNB', 'slug': 'bnb', 'symbol': 'BNB', 'token_address': '0xa05cCD2F8ac92afE092A7240E948aA3E17cEF843'}, 'date_added': '2025-08-27T07:15:15.000Z', 'twitter_username': 'BnbTigerInu_off', 'is_hidden': 0, 'date_launched': '2025-08-24T00:00:00.000Z', 'contract_address': [{'contract_address': '0xa05cCD2F8ac92afE092A7240E948aA3E17cEF843', 'platform': {'name': 'BNB Smart Chain (BEP20)', 'coin': {'id': '1839', 'name': 'BNB', 'symbol': 'BNB', 'slug': 'bnb'}}}], 'self_reported_circulating_supply': 100000000, 'self_reported_tags': ['Memes', 'Binance Chain', 'AI Memes', 'Animal Memes', 'Binance Alpha'], 'self_reported_market_cap': 7917.733362145475, 'infinite_supply': False}, {'id': 33346, 'name': 'BINOVA', 'symbol': 'BNB', 'category': 'token', 'description': 'BINOVA (BNB) is a cryptocurrency launched in 2024and operates on the BNB Smart Chain (BEP20) platform. BINOVA has a current supply of 1,000,000,000 with 0 in circulation. The last known price of BINOVA is 0.00004727 USD and is up 0.00 over the last 24 hours. More information can be found at https://seagull-sam.com/.', 'slug': 'seagull-sam', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/33346.png', 'subreddit': '', 'notice': '', 'tags': ['memes'], 'tag-names': ['Memes'], 'tag-groups': ['INDUSTRY'], 'urls': {'website': ['https://seagull-sam.com/'], 'twitter': ['https://twitter.com/seagull_sam_'], 'message_board': [], 'chat': ['https://t.me/seagull_sam'], 'facebook': [], 'explorer': ['https://bscscan.com/token/0x2bb8862f055be989383092402ff75c7ccfea790e', 'https://app.nansen.ai/token-god-mode?chain=bnb&tab=transactions&tokenAddress=0x2bb8862f055be989383092402ff75c7ccfea790e'], 'reddit': [], 'technical_doc': [], 'source_code': [], 'announcement': []}, 'platform': {'id': '1839', 'name': 'BNB', 'slug': 'bnb', 'symbol': 'BNB', 'token_address': '0x2bb8862f055be989383092402ff75c7ccfea790e'}, 'date_added': '2024-10-08T05:39:38.000Z', 'twitter_username': 'seagull_sam_', 'is_hidden': 0, 'date_launched': '2024-09-06T00:00:00.000Z', 'contract_address': [{'contract_address': '0x2bb8862f055be989383092402ff75c7ccfea790e', 'platform': {'name': 'BNB Smart Chain (BEP20)', 'coin': {'id': '1839', 'name': 'BNB', 'symbol': 'BNB', 'slug': 'bnb'}}}], 'self_reported_circulating_supply': 100000000, 'self_reported_tags': None, 'self_reported_market_cap': 0, 'infinite_supply': False}]}})
print(bnb_cmc['data'].columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28080\1366575378.py in ?()
#       1 bnb_cmc = pd.DataFrame({'status': {'timestamp': '2025-10-18T16:51:43.785Z', 'error_code': 0, 'error_message': None, 'elapsed': 22, 'credit_count': 1, 'notice': None}, 'data': {'BNB': [{'id': 1839, 'name': 'BNB', 'symbol': 'BNB', 'category': 'coin', 'description': 'BNB (BNB) is a cryptocurrency . BNB has a current supply of 139,180,845.25. The last known price of BNB is 1,083.71292096 USD and is up 0.65 over the last 24 hours. It is currently trading on 2825 active market(s) with $4,063,453,973.33 traded over the last 24 hours. More information can be found at https://bnbchain.org/en.', 'slug': 'bnb', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/1839.png', 'subreddit': 'bnbchainofficial', 'notice': '', 'tags': ['marketplace', 'centralized-exchange', 'payments', 'smart-contracts', 'alameda-research-portfolio', 'multicoin-capital-portfolio', 'bnb-chain-ecosystem', 'layer-1', 'alleged-sec-securities', 'celsius-bankruptcy-estate', 'binance-ecosystem', 'binance-listing', 'made-in-china'], 'tag-names': ['Marketplace', 'Centralized Exchange (CEX) Token', 'Payments', 'Smart Contracts', 'Alameda Research Portfolio', 'Multicoin Capital Portfolio', 'BNB Chain Ecosystem', 'Layer 1', 'Alleged SEC Securities', 'Celsius Bankruptcy Estate', 'Binance Ecosystem', 'Binance Listing', 'Made in China'], 'tag-groups': ['INDUSTRY', 'CATEGORY', 'INDUSTRY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'PLATFORM', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY'], 'urls': {'website': ['https://bnbchain.org/en'], 'twitter': ['https://twitter.com/bnbchain'], 'message_board': [], 'chat': ['https://t.me/BNBchaincommunity', 'https://t.me/bnbchain'], 'facebook': [], 'explorer': ['https://explorer.bnbchain.org/', 'https://app.nansen.ai/token-god-mode?chain=ethereum&tab=transactions&tokenAddress=0xb8c77482e45f1f44de1745f52c74426c631bdd52', 'https://bsctrace.com/', 'https://bscscan.com/token/0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c', 'https://www.okx.com/web3/explorer/bsc'], 'reddit': ['https://reddit.com/r/bnbchainofficial'], 'technical_doc': [], 'source_code': ['https://github.com/bnb-chain'], 'announcement': []}, 'platform': None, 'date_added': '2017-07-25T00:00:00.000Z', 'twitter_username': 'bnbchain', 'is_hidden': 0, 'date_launched': None, 'contract_address': [{'contract_address': '0xb8c77482e45f1f44de1745f52c74426c631bdd52', 'platform': {'name': 'Ethereum', 'coin': {'id': '1027', 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum'}}}, {'contract_address': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee', 'platform': {'name': 'BNB Smart Chain (BEP20)', 'coin': {'id': '1839', 'name': 'BNB', 'symbol': 'BNB', 'slug': 'bnb'}}}], 'self_reported_circulating_supply': None, 'self_reported_tags': None, 'self_reported_market_cap': None, 'infinite_supply': False}, {'id': 38157, 'name': 'BNB AI', 'symbol': 'BNB', 'category': 'token', 'description': 'BNB AI (BNB) is a cryptocurrency launched in 2025and operates on the BNB Smart Chain (BEP20) platform. BNB AI has a current supply of 139,000,000 with 0 in circulation. The last known price of BNB AI is 0.00013723 USD and is up 1.95 over the last 24 hours. It is currently trading on 1 active market(s) with $0.00 traded over the last 24 hours. More information can be found at https://bnbaitoken.xyz.', 'slug': 'bnb-ai', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/38157.png', 'subreddit': '', 'notice': 'Please note that this asset is not affiliated with [BNB Chain](https://www.bnbchain.org/en) in any way. Please exercise caution and [DYOR](https://support.coinmarketcap.com/hc/en-us/articles/360043659351-Listings-Criteria).', 'tags': ['memes', 'bnb-chain-ecosystem'], 'tag-names': ['Memes', 'BNB Chain Ecosystem'], 'tag-groups': ['INDUSTRY', 'PLATFORM'], 'urls': {'website': ['https://bnbaitoken.xyz'], 'twitter': ['https://twitter.com/BNBai_off'], 'message_board': [], 'chat': ['https://t.me/bnbaitoken'], 'facebook': [], 'explorer': ['https://bscscan.com/token/0x3376C5632f8047D ...
# ----> 2 print(bnb_cmc['data'].columns.tolist())
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
